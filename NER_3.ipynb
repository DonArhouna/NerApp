# %%
# Importation des libraries et packages que nous allons utiliser
import pandas as pd
import numpy as np
import spacy
import random
from spacy.training.example import Example
from itertools import product
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt

# %% [markdown]
# # I) Preprcessing

# %% [markdown]
# ## I) 1- Importation des donnees

# %%
# Ouvrir les fichiers texte (Train.txt, dev.txt et Test.txt) et lire son contenu ligne par ligne
with open("../train.txt", "r", encoding="utf-8") as file:
    train = file.readlines()
    
with open("../test.txt", "r", encoding="utf-8") as file:
    test = file.readlines()

# %% [markdown]
# ## I) 2- Definition du model

# %%
# Definition du model sous forme de classe
class NER_WOLOF:
        
    def __init__(self):
        
        pass
    
    '''Definition d'une methode qui formate les donnees texte au format que consomme Spacy cad une liste ou chaque
    represente un tuple dont le 1er element est une phrase et le 2em un dictionnaire avec comme clé entitie et comme
    valeur une liste des entitées nommees qui sont des tuples de 3 elements : les index de debut et fin et les entites
    '''
    

    def format_train(self, X):
        # Liste de lignes au format CoNLL
        self.X = X
        # Initialisation de la liste TRAIN_DATA
        data = []

        # Initialisation des variables pour collecter les phrases et leurs annotations
        phrase = []
        annotations = []

        # Parcourir les lignes
        for ligne in self.X:
            # Ignorez les lignes vides
            if not ligne.strip():
                # Si c'est une ligne vide, cela signifie la fin de la phrase précédente
                # Ajoutez la phrase précédente avec ses annotations à TRAIN_DATA
                if phrase and annotations:
                    data.append((" ".join(phrase), {'entities': annotations}))

                # Réinitialisez les variables pour la nouvelle phrase
                phrase = []
                annotations = []
            else:
                # Séparez chaque ligne en tokens et étiquettes
                token, entite = ligne.split()

                # regrouper les entites nommees
                if entite in ["B-PER", "I-PER"]:
                    entite = "PER"
                if entite in ["B-ORG", "I-ORG"]:
                    entite = "ORG"
                if entite in ["B-DATE", "I-DATE"]:
                    entite = "DATE"
                if entite in ["B-LOC", "I-LOC"]:
                    entite = "LOC"


                # Ajoutez le token à la phrase
                phrase.append(token)

                # Si c'est une entité, ajoutez son début, sa fin et son type aux annotations
                if entite != 'O':
                    annotations.append((len(' '.join(phrase)) - len(token), len(' '.join(phrase)), entite))
                    
        return data
                    
    
    def format_test (self, X):
            
        self.X = X
        # Initialisation de la liste data
        data = []

        # Initialisation des variables pour collecter les phrases et leurs annotations
        phrase = []
        annotations = []

        # Parcourir les lignes
        for ligne in self.X:
            # Ignorez les lignes vides
            if not ligne.strip():
                # Si c'est une ligne vide, cela signifie la fin de la phrase précédente
                # Ajoutez la phrase précédente avec ses annotations à TRAIN_DATA
                if phrase and annotations:
                    data.append((" ".join(phrase), {'entities': annotations}))

                # Réinitialisez les variables pour la nouvelle phrase
                phrase = []
                annotations = []
            else:
                
                # Séparez chaque ligne en tokens et étiquettes
                token, entite = ligne.split()
                
                # regrouper les entites nommees
                if entite in ["B-PER", "I-PER"]:
                    entite = "PER"
                if entite in ["B-ORG", "I-ORG"]:
                    entite = "ORG"
                if entite in ["B-DATE", "I-DATE"]:
                    entite = "DATE"
                if entite in ["B-LOC", "I-LOC"]:
                    entite = "LOC"

                # Ajoutez le token à la phrase
                phrase.append(token)

                # ajoutez son début, sa fin et l'entité nommée aux annotations
                annotations.append((len(' '.join(phrase)) - len(token), len(' '.join(phrase)), entite))
                    
        return data
    
    
    
    ''' Definition d'une fonction qui instancie un model vide de Spacy et qui l'entraine selon nos donnees etiquettees
    et les hyperparametres qu'on lui aura donnes
    
    '''
    
    def fit(self, train, n_iter, size, drop):
        
        self.train = train
        self.n_iter = n_iter
        self.size = size
        self.drop = drop
        
        # Création d'un modèle vide
        nlp = spacy.blank("xx")

        # Creation d'un composant NER
        ner = nlp.add_pipe("ner")

        # Ajout des étiquettes d'entités personnalisées
        ner.add_label("PER")
        ner.add_label("ORG")
        ner.add_label("LOC")
        ner.add_label("DATE")


        # Entrainement du modèle avec l'optimizer de base de Spacy Adam qui est plus adapté au nlp
        optimizer = nlp.begin_training()
        # stockage des valeurs de perte au fil des iterations
        loss_values = []  

        for itn in range(self.n_iter):
            #random.shuffle(self.train)
            losses = {}

            # Divisez les données en minibatch
            for batch in spacy.util.minibatch(self.train, size = self.size):
                texts, annotations = zip(*batch)
                example = []
                for i in range(len(texts)):
                    doc = nlp.make_doc(texts[i])
                    example.append(Example.from_dict(doc, annotations[i]))

                # Mettez à jour le modèle
                nlp.update(example, drop = self.drop, losses = losses)

            loss_values.append(losses["ner"])
            print(losses, " Iter n: ", itn)

        return nlp

    ''' Definition d'une methode qui permet de predire un jeu de données '''
    
    # Cette methode permet d'éclater les PER en B-PER, I-PER et pour les autres étiquettes
    '''On itere sur la liste de phrases et on va recuperer les étiquettes pour iterer sur les etiquettes de la phrase
    pour la 1ere iteration on ajoute le préfixe "B-" sinon on verifie si l'entite précédente est la meme et qu'elles 
    se suivent si c'est le cas on ajoute le prefixe "I-" sinon dans tous les autres cas on ajoute le prefixe "B-"
    '''
    def _predict (self, X) :
        self.X = X
        L = []
        for x in self.X:
            l = []
            for j in range(len(x)) :
                if x[j][2] == "O":
                    l.append((x[j][0], x[j][1], "O"))
                elif j == 0 and  x[j][2] != "O":
                    l.append((x[j][0], x[j][1], "B-" + x[j][2]))
                elif (x[j-1][2] == x[j][2] or x[j-1][2] == "I-" + x[j][2]) and x[j-1][1] == x[j][0] - 1 :
                    l.append((x[j][0], x[j][1], "I-" + x[j][2]))
                else :
                    l.append((x[j][0], x[j][1], "B-" + x[j][2]))

            L.extend(l)

        return L


        return 
    
    # Methode pour prédire des donnees de format Spacy
    def predict(self, model, test):
        
        self.nlp = model
        self.test = test
        
        # Analysez les données de test avec le modèle
        predictions = []
        annotations = []

        for texte, annotation_correcte in self.test:
            # on recupere les etiquette de la phrase qu'on ajoute à la liste annotations
            annotations.append(annotation_correcte['entities'])
            # on fait de meme avec une nouvelle liste de prediction ponctuelle
            pred = annotation_correcte['entities']
            pred = [(x[0], x[1], "O") for x in pred]
            # on itere sur la liste des predictions ponctuelle avec que des etiquettes a "0"
            for i in range(len(pred)):
                # Prediction avec le model
                if self.nlp(texte[pred[i][0] : pred[i][1]]).ents :
                    pred[i] = (pred[i][0], pred[i][1], self.nlp(texte[pred[i][0] : pred[i][1]]).ents[0].label_ )


            # on ajoute la prediction ponctuelle à la liste de prediction
            predictions.append(pred)
        
        annotations = self._predict(annotations)
        predictions = self._predict(predictions)
        
        # recuperation des labels pour le rapport
        annotations = [annotation[2] for annotation in annotations]
        predictions = [prediction[2] for prediction in predictions]

        return annotations, predictions
    
    # Methode pour predire des Phrases
    def predict_phrase (self, model, X) :
        
        self.model = model
        self.X = X

        L = []
        for x in self.X.split() :
            if self.model(x).ents :
                L.append(self.model(x).ents[0].label_)
            else :
                L.append("O")
        
        return L
            
    
    ''' Implementation d'une methode score'''
    
    def score (self, y_true, y_pred):
        self.annotations = y_true
        self.predictions = y_pred
        # Calculez les scores de performance
        report = classification_report(self.annotations, self.predictions)
        
        # Recuperation du weigthed avg qui donne le score en prennant compte des dimension disproportionnees de chaque classe
        score = float(report.split()[-8])
        
        return score

# %% [markdown]
# ## I) 3- Formattage des donnees

# %%
# Instanciation de la classe NER_WOLOF
ner = NER_WOLOF()
# Utilisation de sa methode format_data pour formatter les donnees train, val et test
train_data = ner.format_train(train)
test_data = ner.format_test(test)

# %%
train_data
# Out:
# [('SAFIYETU BÉEY Céy Koronaa !',
#   {'entities': [(0, 8, 'PER'), (9, 13, 'PER')]}),
#  ('SÉEX TIIJAAN JÉEY ( Xeltukat / Enda - Cacid )',
#   {'entities': [(0, 4, 'PER'),
#     (5, 12, 'PER'),
#     (13, 17, 'PER'),
#     (31, 35, 'ORG'),
#     (38, 43, 'ORG')]}),
#  ('Ci tekkib Paap Aali Jàllo',
#   {'entities': [(10, 14, 'PER'), (15, 19, 'PER'), (20, 25, 'PER')]}),
#  ('Waaye , li ëpp ci samay xalaat ak i seetlu , Afrig la ñeel , sunu Afrig ak ëllëgam .',
#   {'entities': [(45, 50, 'LOC'), (66, 71, 'LOC')]}),
#  ('Bu ko defee , sama xel mi day faral di wër réewi Afrig yi ba ñu daj , bunt bu dul buntu jinne mu fëgg fa , dugg ci biir kër gi , jàngat la fay xew , doxalinu njiit ya fa nekk ak taxawaayu askan wa .',
#   {'entities': [(49, 54, 'LOC')]}),
#  ('Ndaxte , liy màndargaal daanaka réewi Afrig yépp mooy mbir yii may limsi : ndóol , xiif ak mar , ay xarey biir - réew yu dul jeex , ger , njàng mu yàqu yaxeet , ñàkkub liggéey , añs .',
#   {'entities': [(38, 43, 'LOC')]}),
#  ('Waaye , dinaa leen baaxe , ci sama xalaat mu gàtt , sabab yi ma foog ne , ñoo gën a tax Afrig des ginnaaw .',
#   {'entities': [(88, 93, 'LOC')]}),
#  ('Damay sànni ay kàddu yu néew ci waxtaan wi , jéem a joxe samay xalaat ci li nuy dund fii ci Itali .',
#   {'entities': [(92, 97, 'LOC')]}),
#  ('Omar Bolondeŋ Jóob a ngi juddu ci 10eelu fan ci weeru sàttumbar 1946 ca Ñaame , péeyub réewum Niseer .',
#   {'entities': [(0, 4, 'PER'),
#     (5, 13, 'PER'),
#     (14, 18, 'PER'),
#     (34, 40, 'DATE'),
#     (41, 44, 'DATE'),
#     (45, 47, 'DATE'),
#     (48, 53, 'DATE'),
#     (54, 63, 'DATE'),
#     (64, 68, 'DATE'),
#     (72, 77, 'LOC'),
#     (94, 100, 'LOC')]}),
#  ('Mu ngi faatu ci 11eelu fan ci weeru Mee 1973 ca kaso ba woon ca dunub Gore .',
#   {'entities': [(16, 22, 'DATE'),
#     (23, 26, 'DATE'),
#     (30, 35, 'DATE'),
#     (36, 39, 'DATE'),
#     (40, 44, 'DATE'),
#     (70, 74, 'LOC')]}),
#  ('Omar Bolondeŋ Jóob , nag , kàngam la woon ci biir kàngam yi , jànge ca lekkoolu digg - dóom ji ñu duppe Louis - le - Grand ca Pari .',
#   {'entities': [(0, 4, 'PER'),
#     (5, 13, 'PER'),
#     (14, 18, 'PER'),
#     (126, 130, 'LOC')]}),
#  ('Bim fa génnee , mu tàbbi ca daara ju mag joojee ñuy wax École normale supérieure de Saint - Cloud .',
#   {'entities': [(56, 61, 'ORG'),
#     (62, 69, 'ORG'),
#     (70, 80, 'ORG'),
#     (81, 83, 'ORG'),
#     (84, 89, 'ORG'),
#     (92, 97, 'ORG')]}),
#  ('Bokk na ci liy màndargaal dayo daara jooju , mooy ne ki jëkk a jiite réewum Senegaal , Lewópóol Sedaar Seŋoor , ñu ràññee ko lool ci wàllum ladab ak mbind , bëggoon na fa dugg , waaye daa lajj .',
#   {'entities': [(76, 84, 'LOC'),
#     (87, 95, 'PER'),
#     (96, 102, 'PER'),
#     (103, 109, 'PER')]}),
#  ('Am na sax ñuy wax ne , Seŋoor da koo iñaane woon ndam loola , ragal ne dina ko may fitu wujje ak moom ci làngu politig gi , ñeel Senegaal .',
#   {'entities': [(23, 29, 'PER'), (129, 137, 'LOC')]}),
#  ('Àllaaji Omar Taal mi juddu ci atum 1796 ca Fuuta , bokk na ci ñi siggil ba fàww nit ku ñuul ci lislaam .',
#   {'entities': [(0, 7, 'PER'),
#     (8, 12, 'PER'),
#     (13, 17, 'PER'),
#     (30, 34, 'DATE'),
#     (35, 39, 'DATE'),
#     (43, 48, 'LOC')]}),
#  ('Nekkul woon rekk njiitul diine ak tariixa , wànte boroom xam - xam bu gëmoon der bu ñuul la , te fonk dénduw Afrig gépp .',
#   {'entities': [(109, 114, 'LOC')]}),
#  ('( Xaaj bu njëkku laaj - tontook Ndey Koddu Faal , Paap Aali Jàllo ak Daawuda Géy )',
#   {'entities': [(32, 36, 'PER'),
#     (37, 42, 'PER'),
#     (43, 47, 'PER'),
#     (50, 54, 'PER'),
#     (55, 59, 'PER'),
#     (60, 65, 'PER'),
#     (69, 76, 'PER'),
#     (77, 80, 'PER')]}),
#  ('( Ayu - bésu 4eel jàpp 10eelu fan ci weeru Me )',
#   {'entities': [(13, 17, 'DATE'),
#     (18, 22, 'DATE'),
#     (23, 29, 'DATE'),
#     (30, 33, 'DATE'),
#     (34, 36, 'DATE'),
#     (37, 42, 'DATE'),
#     (43, 45, 'DATE')]}),
#  ('Bàyyi wirisu Covid - 19 bi law ngir sabab kiiraayu - mbooloo la Doktoor Paap Musaa Coor digle ngir xeex mbas mi .',
#   {'entities': [(72, 76, 'PER'), (77, 82, 'PER'), (83, 87, 'PER')]}),
#  ('Waaye PorfesoorMusaa Séydi mi jiite Banqaasu feebar yiy wàlle ca loppitaanu Faan , àndul ak xalaat boobule .',
#   {'entities': [(21, 26, 'PER'), (65, 75, 'ORG'), (76, 80, 'ORG')]}),
#  ('Lii la Porfesoor Séydi wax :', {'entities': [(17, 22, 'PER')]}),
#  ('Askanu Senegaal dafa mës a weg i làmmiñam , làmmiñi réew mépp .',
#   {'entities': [(7, 15, 'LOC')]}),
#  ('Kon nag , doomi Senegaal fonk nañu lool seeni làmmiñ , rawatina wolof bi nga xamante ne mooy lëkkale sunu waaso yépp .',
#   {'entities': [(16, 24, 'LOC')]}),
#  ('Waaye , laata looluy am , ndajem - ndeyu - àtte mi , siiwaloon na ci suba si juróomi wutaakon yi war a joŋante ci wote njiitéefu réew mi nu dégmal : Màkki Sàll ( njiitu réew mi ) , Usmaan Sonko , Madike Ñaŋ , Isaa Sàll ak Idiriisa Sekk .',
#   {'entities': [(149, 154, 'PER'),
#     (155, 159, 'PER'),
#     (181, 187, 'PER'),
#     (188, 193, 'PER'),
#     (196, 202, 'PER'),
#     (203, 206, 'PER'),
#     (209, 213, 'PER'),
#     (214, 218, 'PER'),
#     (222, 230, 'PER'),
#     (231, 235, 'PER')]}),
#  ('Waa kujje gi naan , Màkki wëlbati na keesu réew mi , jël xaalis bu - dul jeex jagleel koog saxaar , te askan wiy jànkoonteel i jafe - jafe yu tar .',
#   {'entities': [(20, 25, 'PER')]}),
#  ('Ñu neeti dafa kootoog yoon wi ngir wëlbati kàrt gi , seppi ñenn ciy naataangoom ci joŋante wote bi , Xalifa Sàll ak Karim Wàdd .',
#   {'entities': [(101, 107, 'PER'),
#     (108, 112, 'PER'),
#     (116, 121, 'PER'),
#     (122, 126, 'PER')]}),
#  ('Am sax ñu naan , ki tëgg làmbu dibéer bi ñu génn , te Bàlla Gay wëlbati Móodu Lóo jël ndam li , li mu ko dugge woon mooy juutal xelu nit ñi ba ñu fàtte solos bés bi .',
#   {'entities': [(31, 37, 'DATE'),
#     (54, 59, 'PER'),
#     (60, 63, 'PER'),
#     (72, 77, 'PER'),
#     (78, 81, 'PER')]}),
#  ('Nimbir yiy doxe diggante nguur geek kujje gi bi Màkki Sáll toogee ci jal bi ba tey jii , dalul xel dara .',
#   {'entities': [(48, 53, 'PER'), (54, 58, 'PER')]}),
#  ('Nun ñépp a ànd ci demokaraasi , waaye ni ko peresidaŋ Sàll gise — ku am doole danga koy wone , doo maye dara , doo yërëm kenn — mën naa jur ëllëg musiba ci réew mi .',
#   {'entities': [(54, 58, 'PER'), (140, 145, 'DATE')]}),
#  ('Senegaal , waxtaan ba juboo lanu xam , lu fi am solo .',
#   {'entities': [(0, 8, 'LOC')]}),
#  ('Bu nu ànduleek sunu sago , am nay réew yu mag ak i boroom doole dinañ jéem a salfaañe Senegaal ngir rekk aakimu alal jooju .',
#   {'entities': [(86, 94, 'LOC')]}),
#  ('Dige géej , téere kilib bii Séex Aliyu Ndaw di door a génne , OSAD mi Soxna Aram Faal jiite moo ko móol ci atum 2019 .',
#   {'entities': [(28, 32, 'PER'),
#     (33, 38, 'PER'),
#     (39, 43, 'PER'),
#     (62, 66, 'ORG'),
#     (70, 75, 'PER'),
#     (76, 80, 'PER'),
#     (81, 85, 'PER'),
#     (107, 111, 'DATE'),
#     (112, 116, 'DATE')]}),
#  ('Du guléet Séex Ndaw di bind kilib ci wolof , Dige géej mooy ñetteelam , ginnaaw Guy Njulli ak Bokk Afrig .',
#   {'entities': [(10, 14, 'PER'), (15, 19, 'PER'), (99, 104, 'LOC')]}),
#  ('Senegaal , jamono ji ñu tollu nii dafa mel ni nekk doomuréew mi rekk doyatul ; fàww nga fésal wet gi nga féete , moo xam sa diine la walla sa tarixa mbaa pàrti pólitig bi nga faral ba ci sax mbootaay gi nga bokk léeg - léeg .',
#   {'entities': [(0, 8, 'LOC')]}),
#  ('Usmaan Sonko nëbbu ko kenn : mébétam mooy jot ci réewum Senegaal ci guddig dibéeru 24 féwaryee 2019 , wuutu Maki Sàll .',
#   {'entities': [(0, 6, 'PER'),
#     (7, 12, 'PER'),
#     (56, 64, 'LOC'),
#     (68, 74, 'DATE'),
#     (75, 82, 'DATE'),
#     (83, 85, 'DATE'),
#     (86, 94, 'DATE'),
#     (95, 99, 'DATE'),
#     (108, 112, 'PER'),
#     (113, 117, 'PER')]}),
#  ('Jàpp naa ne pólitig du liggéey , jàngale mooy sama liggéey ( Isaa Sàll )',
#   {'entities': [(61, 65, 'PER'), (66, 70, 'PER')]}),
#  ('Maaraa la ko ay jegeñaaleem di woowe , doomi - réew mi naan ko Idi .',
#   {'entities': [(63, 66, 'PER')]}),
#  ('Idiriisa Sekk — mooy turam dëggëntaan — dib pólitiseŋ bu ñu ràññee ci Senegaal , Cees la fekk baax .',
#   {'entities': [(0, 8, 'PER'),
#     (9, 13, 'PER'),
#     (70, 78, 'LOC'),
#     (81, 85, 'LOC')]}),
#  ('Ci ginnaaw gi la doon njiitu Ndajem diiwaanu Cees ba nëgëni - sii .',
#   {'entities': [(45, 49, 'LOC')]}),
#  ('Ndekete Fàllu Siise daa bokk ca ña daamar ( kamiyoŋ ) ga saaraan fan yii ñu génn ca Caaroy dal seen kaw .',
#   {'entities': [(8, 13, 'PER'),
#     (14, 19, 'PER'),
#     (65, 68, 'DATE'),
#     (84, 90, 'LOC')]}),
#  ('Altine 6eelu fan ci weeru Me , atum 2019 .',
#   {'entities': [(0, 6, 'DATE'),
#     (7, 12, 'DATE'),
#     (13, 16, 'DATE'),
#     (20, 25, 'DATE'),
#     (26, 28, 'DATE'),
#     (31, 35, 'DATE'),
#     (36, 40, 'DATE')]}),
#  ('Saartjie Baartman ab jaam la woon , fekkoon baax ca réewum Afrig - bëj - saalum .',
#   {'entities': [(0, 8, 'PER'),
#     (9, 17, 'PER'),
#     (59, 64, 'LOC'),
#     (67, 70, 'LOC'),
#     (73, 79, 'LOC')]}),
#  ('Moom , nag , benn doomu Àngalteer lañu ko jaayoon .',
#   {'entities': [(24, 33, 'LOC')]}),
#  ('Ci atum 1810 la àgg Tugal .',
#   {'entities': [(3, 7, 'DATE'), (8, 12, 'DATE')]}),
#  ('Bi mu àggee , nag , tubaab yi dañu ko wuññi , gàcc ko , làññi di ko wone ci ja yi ak luuma yi , diggante Àngalteer ak Frãs .',
#   {'entities': [(105, 114, 'LOC'), (118, 122, 'LOC')]}),
#  ('Ci bésub altine , 2eelu fan ci weeru màrs , atum 2020 la Covid - 19 bi ganesi Senegaal .',
#   {'entities': [(9, 15, 'DATE'),
#     (18, 23, 'DATE'),
#     (24, 27, 'DATE'),
#     (31, 36, 'DATE'),
#     (37, 41, 'DATE'),
#     (44, 48, 'DATE'),
#     (49, 53, 'DATE'),
#     (78, 86, 'LOC')]}),
#  ('Xibaar baa ngi tukke woon ci jawriñ Abdulaay Juuf Saar mi yor wàllu wér - gi - yaram ak ndimbalug mbootaay gi .',
#   {'entities': [(36, 44, 'PER'), (45, 49, 'PER'), (50, 54, 'PER')]}),
#  ('Benn doomu Farãs a ko indaale woon .', {'entities': [(11, 16, 'LOC')]}),
#  ('Doktoor ya nekk ca Institut Pasteur tey saytu lépp lu aju ci jàngoro ji ñoo dëggaloon xibaar bi .',
#   {'entities': [(19, 27, 'ORG'), (28, 35, 'ORG')]}),
#  ('Yéenekaay yépp xéye ko ci talaata ji , def ko ci seen i xët yu njëkk .',
#   {'entities': [(26, 33, 'DATE')]}),
#  ('Ñu ne déet - a - waay , ci talaata ji , 3eelu fan ci weeru màrs , ñu gisaat beneen tubaab , ab farañse bu am 80i at bu ame covid - 19 bi : muy 2 aji - tawat .',
#   {'entities': [(27, 34, 'DATE'),
#     (40, 45, 'DATE'),
#     (46, 49, 'DATE'),
#     (50, 52, 'DATE'),
#     (53, 58, 'DATE'),
#     (59, 63, 'DATE')]}),
#  ('Ca ëllëg sa , 4eelu fan , jawriñ ji génnewaat beneen yëgle , di ci wax ne Institut Pasteur fekkaat na doomu - jàngoro ji ci dereti yeneen ñaari nit .',
#   {'entities': [(3, 8, 'DATE'),
#     (9, 11, 'DATE'),
#     (14, 19, 'DATE'),
#     (20, 23, 'DATE'),
#     (74, 82, 'ORG'),
#     (83, 90, 'ORG')]}),
#  ('Moom , 29eelu fan ci weeru feewaryee la fi ñëwoon , àndoon ak jëkkër ji .',
#   {'entities': [(7, 13, 'DATE'),
#     (14, 17, 'DATE'),
#     (21, 26, 'DATE'),
#     (27, 36, 'DATE')]}),
#  ('Keneen ki , moom , ab doxandéem bu jóge woon ca réewum Àngalteer la , 33 at la am te mu ngi ganesi woon Senegaal ci 24eelu fan ci weeru feewaryee .',
#   {'entities': [(55, 64, 'LOC'),
#     (104, 112, 'LOC'),
#     (116, 122, 'DATE'),
#     (123, 126, 'DATE'),
#     (127, 129, 'DATE'),
#     (130, 135, 'DATE'),
#     (136, 145, 'DATE')]}),
#  ('Ërob , rawatina Farãs , dañuy xeex ak a bunduxataal tuutaafoni waaso yi ( minorités ethniques ) .',
#   {'entities': [(0, 4, 'LOC'), (16, 21, 'LOC')]}),
#  ('Mamadu Jàllo : Ndax CFA bi baax na ci njaay meek njënd mi , rawati - na bitim - réew ?',
#   {'entities': [(0, 6, 'PER'), (7, 12, 'PER')]}),
#  ('Fan yii weesu , Marie Maurisse , ab taskatu xibaar bu fekk baax Siwis , bind na bataaxal bu jar a bàyyi xel .',
#   {'entities': [(16, 21, 'PER'), (22, 30, 'PER'), (64, 69, 'LOC')]}),
#  ('La muy ciy nettali mooy ñaawtéef yu këri - liggéeyukaay yu mag yiy jaay sigaret ci réewi Afrig yiy def , te sunuy gornamaa ne yàcc di leen seetan .',
#   {'entities': [(89, 94, 'LOC')]}),
#  ('George Floyd , jamono jii , mooy néew bi gën a siiw ci àddina sépp .',
#   {'entities': [(0, 6, 'PER'), (7, 12, 'PER')]}),
#  ('Kon , jaadu na nu laaj lii : bés bu mbas mi xéyee ne mes , naka la Senegaal di mel ?',
#   {'entities': [(67, 75, 'LOC')]}),
#  ('Bi Emmanuel Macron ak Alassane Ouattara defee seen yégle bi ba léegi , ku nekk a ngi àddu ci mbir mi .',
#   {'entities': [(3, 11, 'PER'),
#     (12, 18, 'PER'),
#     (22, 30, 'PER'),
#     (31, 39, 'PER')]}),
#  ('Waaye , kii di Séex Tiijaan Jéey , bokk ci kurélu ” Enda Cacid ” jàpp na ni , méngale googu ñuy méngale ECO bi ak CFA bi njuumte lu réy a réy la .',
#   {'entities': [(15, 19, 'PER'),
#     (20, 27, 'PER'),
#     (28, 32, 'PER'),
#     (52, 56, 'ORG'),
#     (57, 62, 'ORG')]}),
#  ('Ci weneen waxin , dafa am ECO bu CEDEAO ak ECO bu UEMOA .',
#   {'entities': [(33, 39, 'ORG'), (50, 55, 'ORG')]}),
#  ('Loolu lay leeral ci kàddu yii Paap Aali Jàllo bu DEFU WAXU tekki ci wolof .',
#   {'entities': [(30, 34, 'PER'),
#     (35, 39, 'PER'),
#     (40, 45, 'PER'),
#     (49, 53, 'ORG'),
#     (54, 58, 'ORG')]}),
#  ('Ci sama gis - gisu bopp , Móodu - Móodu yi agsi ci diggante atum 1980 ba 2000 wute nañu jëfin ak yeneen tukkikat yi tàmbalee tàbbi Itali ci atum 2000 ba tey jii .',
#   {'entities': [(51, 59, 'DATE'),
#     (60, 64, 'DATE'),
#     (65, 69, 'DATE'),
#     (70, 72, 'DATE'),
#     (73, 77, 'DATE'),
#     (131, 136, 'LOC'),
#     (140, 144, 'DATE'),
#     (145, 149, 'DATE')]}),
#  ('Sëñ bi Jóob , nag , du woon ragal walla tóoyemaan , ni ko ndaw yiy waxe .',
#   {'entities': [(7, 11, 'PER')]}),
#  ('Dafa di sax , ni mu ame woon noonu fit moo taxoon ñu dàq ko , moom ak benn doomu Farãs bu daan wuyoo ci turu Daniel Cohn - Bendit , ca daara ju mag jooju , ci atum 1969 .',
#   {'entities': [(81, 86, 'LOC'),
#     (109, 115, 'PER'),
#     (116, 120, 'PER'),
#     (123, 129, 'PER'),
#     (159, 163, 'DATE'),
#     (164, 168, 'DATE')]}),
#  ('Ndege , Omar Bolondeŋ Jóob dafa xaroon tànki tubéyam , di xeexal askanu Senegal .',
#   {'entities': [(8, 12, 'PER'),
#     (13, 21, 'PER'),
#     (22, 26, 'PER'),
#     (72, 79, 'LOC')]}),
#  ('Mi ngi féete woon ci kóminist yi , daan roy ci doxalinu Mao - Tsé Toung .',
#   {'entities': [(56, 59, 'PER'), (62, 65, 'PER'), (66, 71, 'PER')]}),
#  ('Kurél gi mu bokkoon mësul a juboo ak Seŋoor , foo leen fekkaan , ñu ngay jàmmaarloo .',
#   {'entities': [(37, 43, 'PER')]}),
#  ('Ndaxte , Seŋoor nguurug Farãs la fi toogaloon te , ci wàllu xalaat ak politig , yoonu kapitaalist yi la Farãs ak ñi far ak moom toppoon .',
#   {'entities': [(9, 15, 'PER'), (24, 29, 'LOC'), (104, 109, 'LOC')]}),
#  ('Loolu mi ngi tollook jamonoy xareb suuf ( guerre froide ) bi amoon ci diggante U . R . S . S .',
#   {'entities': [(79, 80, 'LOC'),
#     (81, 82, 'LOC'),
#     (83, 84, 'LOC'),
#     (85, 86, 'LOC'),
#     (87, 88, 'LOC'),
#     (89, 90, 'LOC'),
#     (91, 92, 'LOC')]}),
#  ('( kóminism - sosiyalism ) ak réewum Amerig ( kapitaalism – liberaalism ) .',
#   {'entities': [(36, 42, 'LOC')]}),
#  ('Àddina si xar ñaar : ñii far ak U . R . S . S .',
#   {'entities': [(32, 33, 'LOC'),
#     (34, 35, 'LOC'),
#     (36, 37, 'LOC'),
#     (38, 39, 'LOC'),
#     (40, 41, 'LOC'),
#     (42, 43, 'LOC'),
#     (44, 45, 'LOC')]}),
#  ('miy mujje dooni Riisi , ñeneen ñi far ak Amerig .',
#   {'entities': [(16, 21, 'LOC'), (41, 47, 'LOC')]}),
#  ('Ginnaaw bi mu wedamloowee ay sëriñam , Àllaaji Omar feeñaloon na yeneen i kéemtaan ci daara ja mu nekkoon .',
#   {'entities': [(39, 46, 'PER'), (47, 51, 'PER')]}),
#  ('Baayam boroom xam - xam la woon bu jànge Daaray Pir , doon daara ji gënoon a kowe ci jamono jooju .',
#   {'entities': [(48, 51, 'LOC')]}),
#  ('Yaayam it , Soxna Aadama Ayse , yaaram la woon bu nangoo séy te baax , fonk boroom këram ak wujjam .',
#   {'entities': [(12, 17, 'PER'), (18, 24, 'PER'), (25, 29, 'PER')]}),
#  ('Abdul Karim Jàllo , ab sëriñ bu jànge Gànnaar , jële fa wirdu Tijaan , moo ko jëkk a jox wird wa .',
#   {'entities': [(0, 5, 'PER'),
#     (6, 11, 'PER'),
#     (12, 17, 'PER'),
#     (38, 45, 'LOC')]}),
#  ('ABLAAY JUUF SAAR : Li nu gën a seetlu mooy ne limu way - tawati Covid - 19 day gën di yokku .',
#   {'entities': [(0, 6, 'PER'), (7, 11, 'PER'), (12, 16, 'PER')]}),
#  ('Doktoor Séydu Jàllo ab Farmasiyeŋ la , dib biyólósis ak ancien interne des hopitaux .',
#   {'entities': [(8, 13, 'PER'), (14, 19, 'PER')]}),
#  ('Afrig ba Afrig daj , li ko dale Keer ba Peretoryaa , Ndakaaru jàpp Adis - Abebaa , wax ji benn la : jàppal wakseŋ fii , bàyyil wakseŋ fee .',
#   {'entities': [(0, 5, 'LOC'),
#     (9, 14, 'LOC'),
#     (32, 36, 'LOC'),
#     (40, 50, 'LOC'),
#     (53, 61, 'LOC'),
#     (67, 71, 'LOC'),
#     (74, 80, 'LOC')]}),
#  ('Ca njalbéen ga , dañu ko waroon a dawal Soraano ngir ñu bare mën ko faa seetaani .',
#   {'entities': [(40, 47, 'ORG')]}),
#  ('Jamono jooju , Usmaan Jaxatee nekkoon njiitu tiyaatar bi .',
#   {'entities': [(15, 21, 'PER'), (22, 29, 'PER')]}),
#  ('Mujj gi mu jóge fa , dellu UCAD , kenn toppatootul kilibu Séex Ndaw bi , mu nelaw fa diirub daanaka fukki at ak ñaar laata boroom di ko nangu ngir móol - lu ko .',
#   {'entities': [(27, 31, 'ORG'), (58, 62, 'PER'), (63, 67, 'PER')]}),
#  ('Doktoor Séydu Jàllo ab farmasiyeŋ la , dib biyólósis .',
#   {'entities': [(8, 13, 'PER'), (14, 19, 'PER')]}),
#  ('Ci ñaareelu xaaj bii , day biral njàngatam ci mbas mi ñeel Senegaal , niwaakin bi ak coowal ñakk li .',
#   {'entities': [(59, 67, 'LOC')]}),
#  ('Bu teyee ñu ni ay doxandéem a koy jàppale , di ko may xaalis bu dul jeex bu mu làq bitim - réew , bu ëllëg saa ñu ni salafist la , faalewul sunu tariixa yi ; Mustafaa Siise Lóo sax dem na ba ni mook way - fippu Kaasamaas yee bokk gis - gis .',
#   {'entities': [(101, 106, 'DATE'),
#     (158, 166, 'PER'),
#     (167, 172, 'PER'),
#     (173, 176, 'PER'),
#     (211, 220, 'LOC')]}),
#  ('Isaa Sàll , ab wutaakon la ci wote palug njiitu réew mi ñu dégmal , bésub 24eelu féewaryee .',
#   {'entities': [(0, 4, 'PER'),
#     (5, 9, 'PER'),
#     (74, 80, 'DATE'),
#     (81, 90, 'DATE')]}),
#  ('Moom , nag , mébétam mooy bett nit ñi , ni pàrteem bii di PUR bettee woon ñépp ci wote ndawi Péncum réew mi .',
#   {'entities': [(58, 61, 'ORG')]}),
#  ('Dawalkatu roppëlaan , kàngamu xamtéef , njiitu daara - ju - kawe … Ñett a ngoog ci fukki mbir yees war a xam ci Isaa Sàll .',
#   {'entities': [(112, 116, 'PER'), (117, 121, 'PER')]}),
#  ('Ci atum 1988 la Idiriisa Sekk ganesi làngu pólitig gi , waa Senegaal tàmbalee xàmmee xar - kanamam .',
#   {'entities': [(3, 7, 'DATE'),
#     (8, 12, 'DATE'),
#     (16, 24, 'PER'),
#     (25, 29, 'PER'),
#     (60, 68, 'LOC')]}),
#  ('Foo fekkaan ngóor su gàtt soosu te ñuul , mi ngi topp ci ginnaaw Ablaay Wàdd .',
#   {'entities': [(65, 71, 'PER'), (72, 76, 'PER')]}),
#  ('Dëkkoo - dëkk wër nañu ko , ñoom ñaar , di sàkku baatu askan wi ngir góor gi Wàdd toog ci jal bi .',
#   {'entities': [(77, 81, 'PER')]}),
#  ('Aw askan , bala moo tànn njiitam , war naa seet bu baax jikkoom , seetaat ko , xam mooy kan . Looloo waral Lu defu waxu , seen yéenekaay ci kàllaamay Kocc , jóg ngir jagleel wutaakon yi ay xët yuy fésal seen jaar - jaar ak seeni naal ñeel réew mi .',
#   {'entities': [(107, 109, 'ORG'), (110, 114, 'ORG'), (115, 119, 'ORG')]}),
#  ('Maanaam , li yitteel Lu defu waxu moo di xamal leen ñan ñooy dëgg - dëgg ñooñiy wër réew miy soow , te miir bu seeni ndaw gis taf fay nataal yu leen di màndargaal .',
#   {'entities': [(21, 23, 'ORG'), (24, 28, 'ORG'), (29, 33, 'ORG')]}),
#  ('Li nu ko dugge , nag , du lenn lu - dul jox askan wiy tegtal ngir mu tànn ki mu yaakaar ne moo gën ci Senegaal .',
#   {'entities': [(102, 110, 'LOC')]}),
#  ('Fàllu Siise kàggu la woon gu ëmb lu bari ñeel baati wolof ak mbaatiitu wolof .',
#   {'entities': [(0, 5, 'PER'), (6, 11, 'PER')]}),
#  ('Te ni ko fentaakon bu mag boobu di wuyoo ci turu Aamadu Àmpaate Ba waxe , mu am solo lool , Fii ci Afrig , boroom xam - xam bu làqu daa mel ne kàggu gu lakk ” .',
#   {'entities': [(49, 55, 'PER'),
#     (56, 63, 'PER'),
#     (64, 66, 'PER'),
#     (99, 104, 'LOC')]}),
#  ('Njiitalu Olympique de Marseille ba woon , Paap Juuf , faatu na ci guddig talaata ji 31eelu fan ci weeru màrs atum 2020 , ci loppitaanu Faan .',
#   {'entities': [(9, 18, 'ORG'),
#     (19, 21, 'ORG'),
#     (22, 31, 'ORG'),
#     (42, 46, 'PER'),
#     (47, 51, 'PER'),
#     (66, 72, 'DATE'),
#     (73, 80, 'DATE'),
#     (81, 83, 'DATE'),
#     (84, 90, 'DATE'),
#     (91, 94, 'DATE'),
#     (98, 103, 'DATE'),
#     (104, 108, 'DATE'),
#     (109, 113, 'DATE'),
#     (114, 118, 'DATE'),
#     (124, 134, 'ORG'),
#     (135, 139, 'ORG')]}),
#  ('Ndongo Sàmba Silla : Déedéet .',
#   {'entities': [(0, 6, 'PER'), (7, 12, 'PER'), (13, 18, 'PER')]}),
#  ('Ndaxte , boo seetloo , bi Senegaal moomee boppam ci atum 1960 ba nëgëni - sii , li ñuy wax ci tubaab sunu balance commerciale ” dafa deme boor .',
#   {'entities': [(26, 34, 'LOC'), (52, 56, 'DATE'), (57, 61, 'DATE')]}),
#  ('Li Frãs fuloon dayo CFA bi moo waral laago bi .',
#   {'entities': [(3, 7, 'LOC')]}),
#  ('Seŋoor ba Maki , jaare ko ci Abdu Juuf ak Ablaay Wàdd , ku dàq a leb sa moroom nga ne kii .',
#   {'entities': [(0, 6, 'PER'),
#     (10, 14, 'PER'),
#     (29, 33, 'PER'),
#     (34, 38, 'PER'),
#     (42, 48, 'PER'),
#     (49, 53, 'PER')]}),
#  ('Wànte Maki Sàll , sunu njiitu réew mi fi ne , moo ci raw .',
#   {'entities': [(6, 10, 'PER'), (11, 15, 'PER')]}),
#  ('Képp ku koy def , sa bakkan a ngi ci xott , dina la feebarloo , gàttal say fan .',
#   {'entities': [(75, 78, 'DATE')]}),
#  ('Teewul bitig boo dugg Senegaal mu ngay jaay sigaret ; li am ba am moo di ne nguur gee ko daganal , di ci jël moyaal .',
#   {'entities': [(22, 30, 'LOC')]}),
#  ('Li ñu Marie Maurisse di xamal nag , teg ko ci ay firnde yu leer nàññ , moo di ne xeetu sigaret yi ñuy jaay Afrig , ñoo yées fopp yi ñiy jaay Ërob , ca réewi Tubaab ya .',
#   {'entities': [(6, 11, 'PER'),
#     (12, 20, 'PER'),
#     (107, 112, 'LOC'),
#     (141, 145, 'LOC')]}),
#  ('Mën nan koo metitlu waaye warunoo bett ndax Afrig yàgg naa doon Mbëbësu ” Ërob .',
#   {'entities': [(44, 49, 'LOC'), (74, 78, 'LOC')]}),
#  ('Kolobaan gii , boo fa doxantoo , dinga fa fekk ay jali jali fëgg - jaay , maanaam ay yëre yuñ sol Ërob ba sànni leen ci mbalit mi .',
#   {'entities': [(0, 8, 'LOC'), (98, 102, 'LOC')]}),
#  ('Yàggul dara , daaw - jéeg rekk , lanu dégg ni esãs ak gasuwaal bi ñuy jaay fii ci Senegaal ak ci yeneeni réewu Afrig , kenn sañu leen a jaay Fràs walla Almaañ ak ñoom seen .',
#   {'entities': [(82, 90, 'LOC'),
#     (111, 116, 'LOC'),
#     (141, 145, 'LOC'),
#     (152, 158, 'LOC')]}),
#  ('Bees sukkandikoo ci yéenekaayu Amerig bi , ” New York Times ” , lépp a ngi door ci bésub altine , 25eelu fan ci weeru Me .',
#   {'entities': [(31, 37, 'LOC'),
#     (45, 48, 'ORG'),
#     (49, 53, 'ORG'),
#     (54, 59, 'ORG'),
#     (89, 95, 'DATE'),
#     (98, 104, 'DATE'),
#     (105, 108, 'DATE'),
#     (112, 117, 'DATE'),
#     (118, 120, 'DATE')]}),
#  ('Nee ñu , waa jooju , George Floyd la tuddoon .',
#   {'entities': [(21, 27, 'PER'), (28, 33, 'PER')]}),
#  ('Moom , George Floyd , wattuwaafoonu kaaraange la woon ci benn feccukaayu guddi .',
#   {'entities': [(7, 13, 'PER'), (14, 19, 'PER')]}),
#  ('Lii la Jéey wax ci nasaraan :', {'entities': [(7, 11, 'PER')]}),
#  ('Deesul a nàttable ne , diirub 400i at yi tubaab yi moomoon Afrig cib jay doole ak i nax , am nay njeexital yu bir ci nekkinu Afrig ba sunu - jonni - Yàlla - tey jii .',
#   {'entities': [(59, 64, 'LOC'), (125, 130, 'LOC')]}),
#  ('Su ma nexee joxe misaal ci Farãs , Àngalteer walla sax Etaasini .',
#   {'entities': [(27, 32, 'LOC'), (35, 44, 'LOC'), (55, 63, 'LOC')]}),
#  ('Waaye , alal ak doole yi suuxat seen koom , Afrig la bawoo .',
#   {'entities': [(44, 49, 'LOC')]}),
#  ('Bi mu ñibbisee Ndakaaru , mu wéyal xeex boobu ci ndimbaluy rakkam .',
#   {'entities': [(15, 23, 'LOC')]}),
#  ('Ñoom ñépp ñu doon xeex nooteel , teg ci di ŋàññ doxalinu Seŋoor mi doon wéy ci waawi Farãs .',
#   {'entities': [(57, 63, 'PER'), (85, 90, 'LOC')]}),
#  ('Seŋoor demoon na sax ba jël Jean Collin , di doomu Farãs , boole ci di jegeñaale Jacques Foccart , toftal ko ci boppam , dénk ko lépp lu jëm ci kaaraange biir réew mi .',
#   {'entities': [(0, 6, 'PER'),
#     (28, 32, 'PER'),
#     (33, 39, 'PER'),
#     (51, 56, 'LOC'),
#     (81, 88, 'PER'),
#     (89, 96, 'PER')]}),
#  ('Àllaaji Omar jaaroon na Misra , siggil fa der bu ñuul .',
#   {'entities': [(0, 7, 'PER'), (8, 12, 'PER'), (24, 29, 'LOC')]}),
#  ('Boroom xam - xami Misra xawoon nanu koo xeeb ngir wirgo deram , wànte bim jëflaanteek ñoom ba noppi , ñoom ñépp a luum .',
#   {'entities': [(18, 23, 'LOC')]}),
#  ('Usmaan S onko , g i nnaaw bin la nuyoo , noo ngi lay sant di la gërëm bu baax .',
#   {'entities': [(0, 6, 'PER'), (7, 8, 'PER'), (9, 13, 'PER')]}),
#  ('Nu y fàttali rekk ni yaay njiitu Pastef - Les Patriotes .',
#   {'entities': [(33, 39, 'ORG'), (42, 45, 'ORG'), (46, 55, 'ORG')]}),
#  ('Yéenekaayu web Lu Defu Waxu mi ngi lay jaaj ë fal ci li nga nu nangul jotaayu laaj - tontu bii .',
#   {'entities': [(15, 17, 'ORG'), (18, 22, 'ORG'), (23, 27, 'ORG')]}),
#  ('LU DEFU WAXU , nag , mooy yéenekaayub web ci kàllaamay Kocc bees fi jëkk a taxawal .',
#   {'entities': [(0, 2, 'ORG'), (3, 7, 'ORG'), (8, 12, 'ORG')]}),
#  ('Bu ko defee , nu bàyyi la nga nuyook jàngkati LU DEFU WAXU yi laata nuy s ó obu ci waxtaan wi .',
#   {'entities': [(46, 48, 'ORG'), (49, 53, 'ORG'), (54, 58, 'ORG')]}),
#  ('Ci ndaje mu jawriñu wér - gi - yaram ji doon amal ak taskati xibaar yi la Porfesoor Séydi indee leeral yile .',
#   {'entities': [(84, 89, 'PER')]}),
#  ('SUDAŋ : Nguur gi jël na dogal buy méngale xarafal jigéen ak rey nit .',
#   {'entities': [(0, 5, 'LOC')]}),
#  ('Paap Aali Jàllo : Ginnaaw bin la nuyoo , noo ngi lay ñaan nga wax jàngkati Lu defu waxu yi kan mooy Séydu Jàllo .',
#   {'entities': [(0, 4, 'PER'),
#     (5, 9, 'PER'),
#     (10, 15, 'PER'),
#     (75, 77, 'ORG'),
#     (78, 82, 'ORG'),
#     (83, 87, 'ORG'),
#     (100, 105, 'PER'),
#     (106, 111, 'PER')]}),
#  ('Dafa am ay Móodu - Móodu ak ay Faatu - Faatu yu def ay widewoo di ci aartu seen i mbokk ak askanu Afrig wépp .',
#   {'entities': [(98, 103, 'LOC')]}),
#  ('Liñ ci jublu woon , ci seen i wax , mooy xamal leen ne , ci réewi Ërob yeek Amerig yi , am na ciy mbooloo yu laxasaayoo lëndëm , di lal ay pexe ngir wàññi limu nit ñi ci àddina si , te fas ko yéene tàmbalee Afrig ak nit ñu ñuul ñi .',
#   {'entities': [(66, 70, 'LOC'), (76, 82, 'LOC'), (207, 212, 'LOC')]}),
#  ('Waaye teewul Dige géej mel ni lu bees ndax nekkinu doomi - Afrig yaa ngiy wéy di tar te su dee tukkib nëbbu rekk mel na ni tey la Waalo gën a aay .',
#   {'entities': [(59, 64, 'LOC')]}),
#  ('Paap Aali Jàllo : Noo gise dogal ak matuwaay yi nguuru Senegaal jël ngir xeex mbas mi ?',
#   {'entities': [(0, 4, 'PER'),
#     (5, 9, 'PER'),
#     (10, 15, 'PER'),
#     (55, 63, 'LOC')]}),
#  ('Ruwàndaa bokk na tey ci réew yi ñu gën a naw ci Afrig waaye du tax kenn fàtte la fa xewoon ci atum 1994 .',
#   {'entities': [(0, 8, 'LOC'),
#     (48, 53, 'LOC'),
#     (94, 98, 'DATE'),
#     (99, 103, 'DATE')]}),
#  ('Kodiwaar tamit , démb rekk la woon .', {'entities': [(0, 8, 'LOC')]}),
#  ('Kan nag mooy gone gii wutewul ak cuuraayu dëmm ci Maki Sàll ak i nitam ?',
#   {'entities': [(50, 54, 'PER'), (55, 59, 'PER')]}),
#  ('Ci màrs 1990 la jëkk a doon jawriñ cig nguuru Senegaal .',
#   {'entities': [(3, 7, 'DATE'), (8, 12, 'DATE'), (46, 54, 'LOC')]}),
#  ('Mooy jamono ja Abdu Juuf yaatalee gornmaam , xajal ci kujje gi .',
#   {'entities': [(15, 19, 'PER'), (20, 24, 'PER')]}),
#  ('Ñaari at yi jiitu woon loolu , nag , ay yëngu - yëngu yu metti amoon nañu Senegaal .',
#   {'entities': [(74, 82, 'LOC')]}),
#  ('Idi la Juuf dénkoon njula mi .',
#   {'entities': [(0, 3, 'PER'), (7, 11, 'PER')]}),
#  ('Bu ko defee , nan tàmbaleek Maki Sàll , njiitu réew mi bëgg ñu falaat ko .',
#   {'entities': [(28, 32, 'PER'), (33, 37, 'PER')]}),
#  ('Benn : boroom xam - xam yi mel ne Fàllu Siise duñuy faral di móol i téere di ci dëxéñ xam - xam boobuy tax bu ñu fi jógee mu des fi ba seeni sët ak seeni sëtaat jot ci ba sax gën koo ñoŋal .',
#   {'entities': [(34, 39, 'PER'), (40, 45, 'PER')]}),
#  ('Sëriñ Séex Beeco Cuun , di Xalifa di yit kilifa cantaakon yi .',
#   {'entities': [(6, 10, 'PER'), (11, 16, 'PER'), (17, 21, 'PER')]}),
#  ('Saartjie Baartman as ndaw su jekkoon , ab diriyànke bu amoon waŋ ak i ween yu réy lool la woon .',
#   {'entities': [(0, 8, 'PER'), (9, 17, 'PER')]}),
#  ('Li ko dale altine , 2eelu fan ci weeru màrs ba tey jii , bés bu nekk ñu jot cib yégle bu bawoo ci njawriñu wér - gi - yaram geek ndimbalug mbootaay gi ñeel Covid - 19 biy doxantu ci biir réew mi .',
#   {'entities': [(11, 17, 'DATE'),
#     (20, 25, 'DATE'),
#     (26, 29, 'DATE'),
#     (30, 32, 'DATE'),
#     (33, 38, 'DATE'),
#     (39, 43, 'DATE')]}),
#  ('Paap Juuf mi ngi juddu bésub 18eel weeru desàmbar atum 1951 ca Abese , réewum Càdd .',
#   {'entities': [(0, 4, 'PER'),
#     (5, 9, 'PER'),
#     (29, 34, 'DATE'),
#     (35, 40, 'DATE'),
#     (41, 49, 'DATE'),
#     (50, 54, 'DATE'),
#     (55, 59, 'DATE'),
#     (63, 68, 'LOC'),
#     (78, 82, 'LOC')]}),
#  ('Taskatu xibaar la woon ( liggéey na ci La Marseillaise ak Le Sport ) , nekkoon ndawal futbalkat , manatsëeru tàggat - yaram ak njiitu këlëbu futbal Olympique de Marseille dale ko 2005 ba 2009 .',
#   {'entities': [(39, 41, 'ORG'),
#     (42, 54, 'ORG'),
#     (58, 60, 'ORG'),
#     (61, 66, 'ORG'),
#     (148, 157, 'ORG'),
#     (158, 160, 'ORG'),
#     (161, 170, 'ORG'),
#     (179, 183, 'DATE'),
#     (184, 186, 'DATE'),
#     (187, 191, 'DATE')]}),
#  ('Bi ñu siiwalee li Marie Maurisse bind , Philip Morris , këru liggéeyukaay gu mag gi ubbi fii Senegal ab isinu sigaret , daldi nay tontu .',
#   {'entities': [(18, 23, 'PER'), (24, 32, 'PER'), (93, 100, 'LOC')]}),
#  ('Ñaari mbir a jar a fësal ci li mu wax : bu jëkk bi moo di ne Philip Morris weddiwul ni sigaret yi muy jaay Senegaal ñoo yées yi ñuy jaay Ërob ; ñaareel bi , nag , mooy , sunu wér - gi - yaram gi ñuy fowe , nee na ci li ko nguuru Senegaal may la ko teg .',
#   {'entities': [(107, 115, 'LOC'), (137, 141, 'LOC'), (229, 237, 'LOC')]}),
#  ('Waa OMS , kurél gi ñu dénk lépp lu jëm ci wér - gi - yaram ci àddina si , firndeel nañ ni fileek 2030 , limu tóxkati Afrig yi dina ful ñaari yoon .',
#   {'entities': [(4, 7, 'ORG'), (97, 101, 'DATE'), (117, 122, 'LOC')]}),
#  ('Ërob moom , tàmbalee naa xeex ak doole sigaret , ngir aar ay ndawam , fexe ba ñu bàyyee tóx .',
#   {'entities': [(0, 4, 'LOC')]}),
#  ('Looloo tax defarkati sigaret yu mel ni Philip Morris jàpp ne liggéey ak Afrig moo fi sës , sunu réew yi amal leen lool solo .',
#   {'entities': [(72, 77, 'LOC')]}),
#  ('Bi 19iw57is jotee , lañ woo pólis ne leen George Floyd xaalis bu baaxul la jënde ay sigaret .',
#   {'entities': [(3, 11, 'DATE'), (42, 48, 'PER'), (49, 54, 'PER')]}),
#  ('Nes - tuut , 2i takk - der agsi ca béreb ba , Thomas Lane ak J . Alexander Kueng ; ñu daldi taxaw ci kanamu oto bi George Floyd nekkoon .',
#   {'entities': [(46, 52, 'PER'),
#     (53, 57, 'PER'),
#     (61, 62, 'PER'),
#     (63, 64, 'PER'),
#     (65, 74, 'PER'),
#     (75, 80, 'PER'),
#     (115, 121, 'PER'),
#     (122, 127, 'PER')]}),
#  ('Thomas Lane daldi génne fetelam ci saa si te kenn xamul lu tax mu def ko .',
#   {'entities': [(0, 6, 'PER'), (7, 11, 'PER')]}),
#  ('Ci la sante George Floyd mu teg i loxoom ci wolaŋ bi .',
#   {'entities': [(12, 18, 'PER'), (19, 24, 'PER')]}),
#  ('Noonu , ci diirub 2i simili , Lane roofaat na fetelam ba génne Floyd ci oto bi , takkal koy manot .',
#   {'entities': [(30, 34, 'PER'), (63, 68, 'PER')]}),
#  ('Ci la ko beneen takk - der bi , Kueng , sësale ci benn miir .',
#   {'entities': [(32, 37, 'PER')]}),
#  ('Ba tey , George Floyd fippuwul , xataraayuwul : luñ ko defloo , mu def ko .',
#   {'entities': [(9, 15, 'PER'), (16, 21, 'PER')]}),
#  ('Senegaal war naa soppi doxalinam su bëggee bokk ci réew yiy raw ëllëg .',
#   {'entities': [(0, 8, 'LOC'), (64, 69, 'DATE')]}),
#  ('Bi Alassane Ouattara ak Macron siiwale liñ naal ñeel ECO biñ wax ne mooy wuutu CFA bi ci atum 2020 ba léegi , coow li bare na lool .',
#   {'entities': [(3, 11, 'PER'),
#     (12, 20, 'PER'),
#     (24, 30, 'PER'),
#     (89, 93, 'DATE'),
#     (94, 98, 'DATE')]}),
#  ('Dara waralu ko nag , lu - dul ne ñu bare dañ réere lenn mbir : ECO bi CEDEAO di togg li ko dale atum 2000 ba tey , bokkul ak ECO bi UEMOA bëgg amal .',
#   {'entities': [(70, 76, 'ORG'),
#     (96, 100, 'DATE'),
#     (101, 105, 'DATE'),
#     (132, 137, 'ORG')]}),
#  ('Kon , ñoo ngi jaawale ñaari weccit yu bokkul doonte réewi UEMOA yi bokk nañ ci CEDEAO ak naalub ECO bim sumboon .',
#   {'entities': [(58, 63, 'ORG'), (79, 85, 'ORG')]}),
#  ('Ma bëggoon cee indiy leeral yu am solo ndeem bëgg nanoo sàmm naalub bennale wecciti réewi CEDEAO yi , te muy ECO bu wér bi .',
#   {'entities': [(90, 96, 'ORG')]}),
#  ('Li ma ci namm mooy gindi ci askan wi ngir mu bañ a jaawale ECO bI CEDEAO sumb ( te mooy bu baax bi ) ak ECO bi Alassane Ouattara yégle keroog moom ak Macron te mu ñeel réewi UEMOA yi rekk ( te muy biral ba tey nootaange ) .',
#   {'entities': [(66, 72, 'ORG'),
#     (111, 119, 'PER'),
#     (120, 128, 'PER'),
#     (150, 156, 'PER'),
#     (174, 179, 'ORG')]}),
#  ('Kon , jàppal ni bataaxal bii , jàmm rekk la wund , ñeel nekkinu Mali gi nu bokk ak i doomam , te nga boole leen jiite .',
#   {'entities': [(64, 68, 'LOC')]}),
#  ('Loolu la Omar Bolondeŋ Jóob ak i àndandoom doon xeex .',
#   {'entities': [(9, 13, 'PER'), (14, 22, 'PER'), (23, 27, 'PER')]}),
#  ('Ndax kat , Seŋoor dafa jébbalu woon ci Farãs ba nga xam ne , buñ tisóoliwaan Pari , mu ne yaaram - kàlla .',
#   {'entities': [(11, 17, 'PER'), (39, 44, 'LOC'), (77, 81, 'LOC')]}),
#  ('Am jamono , Seŋoor sumboon fi liggéey bu mag ñeel mbeddi ndakaaru yi , santaane ñu set - setal gox - goxaat yi ngir laabal leen .',
#   {'entities': [(12, 18, 'PER')]}),
#  ('Te , nag , duggewu ko woon lenn lu dul teeru Pompidou mi jiite woon Farãs , ngir bégal ko .',
#   {'entities': [(45, 53, 'PER'), (68, 73, 'LOC')]}),
#  ('Loolu metti lool Omar Bolondeŋ Jóob ak i rakkam ba tax ñu demoon taali Njawriñu Liggéeyu caytu gi ak Kërug aada ak cosaan gu Farãs ci Ndakaaru , ñu doon ko wax Centre culturel français .',
#   {'entities': [(17, 21, 'PER'),
#     (22, 30, 'PER'),
#     (31, 35, 'PER'),
#     (125, 130, 'LOC'),
#     (134, 142, 'LOC'),
#     (160, 166, 'ORG'),
#     (167, 175, 'ORG'),
#     (176, 184, 'ORG')]}),
#  ('Ba mu ajee Màkka la taseek Muhamadu Xaali nekk taalibeem ay weeri weer .',
#   {'entities': [(11, 16, 'LOC'), (27, 35, 'PER'), (36, 41, 'PER')]}),
#  ('Muhamadu Xaali natt ko ci bépp anam , def ko Xalifa ci ndigalu Seex Ahmad Tiijaani .',
#   {'entities': [(0, 8, 'PER'),
#     (9, 14, 'PER'),
#     (63, 67, 'PER'),
#     (68, 73, 'PER'),
#     (74, 82, 'PER')]}),
#  ('Seneraal Farãsuwaa Njaay a xaatim yégle biy wax ne ñiy liggéey ci kurélug Force - Covid giy saytu ak a doxal xeexub mbas mi , feddaliwaat nañ seen yéene ci liggéey ngir Yàlla ci jamonoy mbas mi .',
#   {'entities': [(9, 18, 'PER'), (19, 24, 'PER')]}),
#  ('Coow looloo sababoon sax geddug Abiib Sy mi fa teewaloon kujje gi .',
#   {'entities': [(32, 37, 'PER'), (38, 40, 'PER')]}),
#  ('GINE – BISAAWO : Jàngoroy Covid - 19 bi song na nguuru Gine - Bisaawo , ñetti jawriñ ñoo ko ame : njiital jawriñ li , jawriñu kaaraange biir réew mi ak jawriñu jiñ dénk wér - gi - yaram .',
#   {'entities': [(0, 4, 'LOC'),
#     (7, 14, 'LOC'),
#     (55, 59, 'LOC'),
#     (62, 69, 'LOC')]}),
#  ('Séydu Jàllo : Maa ngi leen di fey , di leen jaajëfal ci li ngeen ma tànn ngir waxtaane mbasum Covid - 19 bi .',
#   {'entities': [(0, 5, 'PER'), (6, 11, 'PER')]}),
#  ('Man , Séydu Jàllo laa tudd .',
#   {'entities': [(6, 11, 'PER'), (12, 17, 'PER')]}),
#  ('Séydu Jàllo : Waaw .', {'entities': [(0, 5, 'PER'), (6, 11, 'PER')]}),
#  ('Nun waa Senegaal nag , li nuy seetaan muy raam , ci ñag bi la jëm .',
#   {'entities': [(8, 16, 'LOC')]}),
#  ('Daanaka bi ñu ko dàqee Impôts et Domaines la ñuy door a dégg turam .',
#   {'entities': [(23, 29, 'ORG'), (30, 32, 'ORG'), (33, 41, 'ORG')]}),
#  ('Isaa Sàll moo jiite pàrti bi ñu duppe PUR .',
#   {'entities': [(0, 4, 'PER'), (5, 9, 'PER'), (38, 41, 'ORG')]}),
#  ('PUR , nag , meloy nëtëx ak weex , ak ñaari picc yi lees koy màndargale .',
#   {'entities': [(0, 3, 'ORG')]}),
#  ('Isaa Sàll ku jar a bàyyi xel la .',
#   {'entities': [(0, 4, 'PER'), (5, 9, 'PER')]}),
#  ('Ndaxte , moo nekkoon mbetteel ci wote ndawi Péncum réew mi yiñ fi amaloon ñaari at ci ginnaaw , doonoon ñeenteelu pàrti bi ëppoon i baat ci Senegaal .',
#   {'entities': [(140, 148, 'LOC')]}),
#  ('Ndege , amoon na 155 000 baat , maanaam téeméer boo jël ci pal googu , lu jege juróomi nit PUR lañu sànniloon kàrt .',
#   {'entities': [(91, 94, 'ORG')]}),
#  ('Àddinay dox ba Ablaay Wàdd duma Abdu Juuf ci atum 2000 , wuutu ko ci jal bi .',
#   {'entities': [(15, 21, 'PER'),
#     (22, 26, 'PER'),
#     (32, 36, 'PER'),
#     (37, 41, 'PER'),
#     (45, 49, 'DATE'),
#     (50, 54, 'DATE')]}),
#  ('Ci la tànne Idi , def ko bëkk - néegam .', {'entities': [(12, 15, 'PER')]}),
#  ('Ci weeru nowàmbar , atum 2002 , nag , la ko Góor - gi ” tabb Njiitu jawriñ ji .',
#   {'entities': [(3, 8, 'DATE'),
#     (9, 17, 'DATE'),
#     (20, 24, 'DATE'),
#     (25, 29, 'DATE')]}),
#  ('Rax - ci - dolli , moo toppoon ci Ablaay Wàdd ci kilifteefu PDS .',
#   {'entities': [(34, 40, 'PER'), (41, 45, 'PER'), (60, 63, 'ORG')]}),
#  ('Ci atum 2000 la askanu Senegaal folli Abdu Juuf , fal Ablaay Wàdd .',
#   {'entities': [(3, 7, 'DATE'),
#     (8, 12, 'DATE'),
#     (23, 31, 'LOC'),
#     (38, 42, 'PER'),
#     (43, 47, 'PER'),
#     (54, 60, 'PER'),
#     (61, 65, 'PER')]}),
#  ('Ñu teg ci fukki at ak ñaar , mu doyal sëkk ci Góor - gi , dàq ko , Maki Sàll daldi toog ci jal bi .',
#   {'entities': [(67, 71, 'PER'), (72, 76, 'PER')]}),
#  ('Bu nu boolee loolu lépp , demug Fàllu Siise gi day doon ci nun ñaari tiis .',
#   {'entities': [(32, 37, 'PER'), (38, 43, 'PER')]}),
#  ('Bóomug Madinatul - Salaam , bile dàkkental la taskati xibaar yi utal mbir mi sabab layoo bu siiw bii .',
#   {'entities': [(7, 16, 'LOC'), (19, 25, 'LOC')]}),
#  ('Juróom - ñaari at la lànket bi def , doore ko 2012 ba 2019 .',
#   {'entities': [(37, 42, 'DATE'),
#     (43, 45, 'DATE'),
#     (46, 50, 'DATE'),
#     (51, 53, 'DATE'),
#     (54, 58, 'DATE')]}),
#  ('Ñépp a doon xaar ndogalu àttekat bii di Xaasimu Ture , mu waroon koo biral ci altine jii .',
#   {'entities': [(40, 47, 'PER'),
#     (48, 52, 'PER'),
#     (78, 84, 'DATE'),
#     (85, 88, 'DATE')]}),
#  ('Mënees na wax ne , Tubaab yi ab mala lañu jàppe woon Saartjie Baartman .',
#   {'entities': [(53, 61, 'PER'), (62, 70, 'PER')]}),
#  ('Ku def jëf ju bon te ñaaw jooju mooy Cuvier , benn doomu Frãs bu doon gëstu xeeti mala yi .',
#   {'entities': [(37, 43, 'PER'), (57, 61, 'LOC')]}),
#  ('Noonu , gannaaw soxna Saartjie Baartman nit ku ñuul la woon , Cuvier da koo boole ci mala yi , saytu ko , amal ay njàngat ci moom .',
#   {'entities': [(22, 30, 'PER'), (31, 39, 'PER'), (62, 68, 'PER')]}),
#  ('Ginnaaw yégle bi jiitu bi génnoon ci altine ji , 2eelu fan ci weeru màrs , jot nañoo génne 18 yégle yiy saabal ci Covid - 19 bi ak dogal yiñ ci jël , lépp di 19 yégle .',
#   {'entities': [(37, 43, 'DATE'),
#     (44, 46, 'DATE'),
#     (49, 54, 'DATE'),
#     (55, 58, 'DATE'),
#     (59, 61, 'DATE'),
#     (62, 67, 'DATE'),
#     (68, 72, 'DATE')]}),
#  ('Yégle bu mujj baa ngi génnoon ci bésub 19eel .',
#   {'entities': [(33, 38, 'DATE'), (39, 44, 'DATE')]}),
#  ('Seen xaalis di gën a yokk ak bu Farãs , askan wi moom di wéy di ndóol .',
#   {'entities': [(32, 37, 'LOC')]}),
#  ('Fii ci Afrig nag , ñu bare jàpp nañ ne , su nu weesoo jamonoy koronaawiris bi , sunu réew yi waratuñoo des ginnaaw .',
#   {'entities': [(7, 12, 'LOC')]}),
#  ('Am sax ñu dem ba yaakaar ne Afrig moo war a aye , jiitu ñi ci des topp ci .',
#   {'entities': [(28, 33, 'LOC')]}),
#  ('Su nu bëggee sunu Senegaal am ndam nag , war nanoo xoolaat sunuy jikko , gën a yar sunu bopp , defaraat sunu nekkin .',
#   {'entities': [(18, 26, 'LOC')]}),
#  ('Moo waral nuy laaj tey : ndax lekoolu Senegaal dina mucc ci tawat bii di koronaawiris ?',
#   {'entities': [(38, 46, 'LOC')]}),
#  ('Bees sukkandikoo ci kàdduy Ouattara - Macron yi , xel mën naa jàpp ne waa UEMOA ñoo xaalatal seen bopp , sos ECO ngir mu wuutu CFA .',
#   {'entities': [(27, 35, 'PER'), (38, 44, 'PER'), (74, 79, 'ORG')]}),
#  ('Dem na ba ñu baree bare ci réew yiy làkk farañse biir Afrig sowu - jant jàpp ne kurélu UEMOA dafa aakimoo ab naal boo xam ne , gaa , bokkoon na ca ña ko laloon , waaye moomu ko .',
#   {'entities': [(54, 59, 'LOC'), (87, 92, 'ORG')]}),
#  ('Li ma ko tax a wax nag , mooy ne , ci biir i waxam , Alassane Ouattara tuddul benn yoon CEDEAO te xam na xéll ne ECO , ci dëgg - dëgg , moomeelu CEDEAO la .',
#   {'entities': [(53, 61, 'PER'),
#     (62, 70, 'PER'),
#     (88, 94, 'ORG'),
#     (145, 151, 'ORG')]}),
#  ('Moom daal , ak ni mu waxe , dafa mel ni UEMOA ak Frãs ñoo toogandoo , xalaat , waxtaan ba déggoo ci ne warees na soppi CFA bi , indi ECO .',
#   {'entities': [(40, 45, 'ORG'), (49, 53, 'LOC')]}),
#  ('Ndege , Luwi XIV , buuru Farãs ba woon , dafa jëloon ab ndogal , yoonal tëralinu njaam gi , biral ci àqi ma - weex yi ak wareefi nit ñu ñuul ñi ñeel leen .',
#   {'entities': [(8, 12, 'PER'), (13, 16, 'PER'), (25, 30, 'LOC')]}),
#  ('Yemuñu ca , ndax defaroon nañ ay ndell , fasoon leen yéenee sànni ci kow woto yi yaboon Seŋoor ak kilifa tubaab yi mu waroon a teeru .',
#   {'entities': [(88, 94, 'PER')]}),
#  ('Jàllo Jóob moom , dañ ko tëjoon Kéedugu giiru dundam ba noppi sas ko liggéey bu mu sañutoon a bañ , dëkke koo metital ak a xorñoññal ca biir kaso ba .',
#   {'entities': [(0, 5, 'PER'), (6, 10, 'PER'), (32, 39, 'LOC')]}),
#  ('Ca la Omar nisëree woon ca Mali ga mu dawoon làqu , ne day afalsiy rakkam , kilifay Bamako tegati ko loxo , jébbal ko nguru Senegaal .',
#   {'entities': [(6, 10, 'PER'),
#     (27, 31, 'LOC'),
#     (84, 90, 'LOC'),
#     (124, 132, 'LOC')]}),
#  ('Àllaaji Omar Taal sumboon nay xare Senegaal ba Niseryaa ngir tuubloo ceddo yi , yaatal lislaam fépp ci Afrig sowu - jànt .',
#   {'entities': [(0, 7, 'PER'),
#     (8, 12, 'PER'),
#     (13, 17, 'PER'),
#     (35, 43, 'LOC'),
#     (47, 55, 'LOC'),
#     (103, 108, 'LOC')]}),
#  ('Ci 1864 la ko noon yi ërtal mu dugg ci Degembeer ne fa mes .',
#   {'entities': [(3, 7, 'DATE'), (39, 48, 'DATE')]}),
#  ('Noo ngi leen di fey bu baax a baax , di nuyu jàngkati LU DEFU WAXU yépp , mag ak ndaw , góor ak jigéen .',
#   {'entities': [(54, 56, 'ORG'), (57, 61, 'ORG'), (62, 66, 'ORG')]}),
#  ('Maa ngi nuyu tamit askanuw Senegaal wépp , ku ci nekk ak foo mënti nekk , di nuyu Afrig gépp ak àddina sépp .',
#   {'entities': [(27, 35, 'LOC'), (82, 87, 'LOC')]}),
#  ('Jullig àjjuma : waa Lewna Ñaseen fippu nañu',
#   {'entities': [(20, 25, 'LOC'), (26, 32, 'LOC')]}),
#  ('COVID - 19 : Nee ñu kenn ci sàndarm yiy aar Maki Sàll ame na jàngoro ji .',
#   {'entities': [(44, 48, 'PER'), (49, 53, 'PER')]}),
#  ('Mu mel ni daal xalaati Malthus , benn boroom xam - xam bu mag bu doon dund ci 19eelu xarnu bi , ca Àngalteer , la ñuy dekkil noonu .',
#   {'entities': [(23, 30, 'PER'), (99, 108, 'LOC')]}),
#  ('Géej nag moom , kumpa la ba jéex ndax , ni ko Séex waxe , ndox mu ne màww ba fu bët yem doy na kéemtaan .',
#   {'entities': [(46, 50, 'PER')]}),
#  ('Yaakaar naa ni sax , li sunu koom - koom aju ci bitim - réew moo taxoon nguur gi teelul woon fatt digi réew mi , maanaam aaye fafalnaaw dugg Senegaal .',
#   {'entities': [(141, 149, 'LOC')]}),
#  ('Usmaan Sonkoo ngi juddoo Cees ci atum 1974 .',
#   {'entities': [(0, 6, 'PER'),
#     (7, 13, 'PER'),
#     (25, 29, 'LOC'),
#     (33, 37, 'DATE'),
#     (38, 42, 'DATE')]}),
#  ('Waaye ginnaaw ay way - juram ndawi gormaa bi lañu woon , Sigicoor la màgge .',
#   {'entities': [(57, 65, 'LOC')]}),
#  ('Yaayam , Maam Xadi Ngom , séeréer la , di yit pulaar , baay biy joolaa .',
#   {'entities': [(9, 13, 'PER'), (14, 18, 'PER'), (19, 23, 'PER')]}),
#  ('Ndoorteelu Isaa Sàll ci làngu pólitig gi',
#   {'entities': [(11, 15, 'PER'), (16, 20, 'PER')]}),
#  ('Ndax kat , bu dee wax dëgg rekk , fu mu mas a jaar , Idi def na fay jaloore yees koy màndargale .',
#   {'entities': [(53, 56, 'PER')]}),
#  ('Bunu fàtte ni ngóor sii ganesi àddina ci atum 1959 , ca Cees , dafa mas di raw ci kalaas yim jaar yépp , ba muy tuut - tànk ba ba muy am bakaloryaa , ñu daan koy faral di ràññee yit ci Concours général .',
#   {'entities': [(41, 45, 'DATE'), (46, 50, 'DATE'), (56, 60, 'LOC')]}),
#  ('Noonu la ko jàppe woon itam , ci njàngum daara yu kawe yim defoon ca Pari ak ca Iniwérsite Princeton bu Amerig .',
#   {'entities': [(69, 73, 'LOC'),
#     (80, 90, 'ORG'),
#     (91, 100, 'ORG'),
#     (104, 110, 'LOC')]}),
#  ('Leneen lu ma seetlu ci jaar - jaaram moo di ne , ak li muy teel a dugg ci làngu pólitig gi yépp — fukki at ak juróom rekk la amoon — Idi jot naa liggéey ci Pirwe bi laata muy bokk ci nguur gi .',
#   {'entities': [(133, 136, 'PER')]}),
#  ('Maki Sàll digewul yem ci .', {'entities': [(0, 4, 'PER'), (5, 9, 'PER')]}),
#  ('Waaye yàggul dara mu tàmbalee indiy tànki bukki , daldi ne , aa , man kat sama yéene rekk laa waxoon , waaye këru - àttekaay gi gën a kowe ci Senegaal nee na du ci dal , fàww ma matal juróom - ñaari at yi , ñu door a seet naka lañuy def .',
#   {'entities': [(142, 150, 'LOC')]}),
#  ('Kon mu mel ni Maki Sàll dafa noo bëggoon a gëmloo ne amoon na lool naqar ci li ko yoon mayul mu wàññi màndaam bu njëkk bi .',
#   {'entities': [(14, 18, 'PER'), (19, 23, 'PER')]}),
#  ('Waaye nag sant Yàlla ndax bi nuy jooy loolu ci la ma Sëriñ Jili Kebe xamal ni Fàllu jotoon naa liggéey ak benn waay ba tax lu bari ci li newoon ci moom yëbb na ko ci waay jooju .',
#   {'entities': [(53, 58, 'PER'),
#     (59, 63, 'PER'),
#     (64, 68, 'PER'),
#     (78, 83, 'PER')]}),
#  ('Rax - ci - dolli , waxtaan yi mu jot a séq ak ña ca kippaango bee ñu duppe Akaademi wolof ci Facebook , baati wolof yu xóot te ñu bari umple leen woon , jot na ko faa rotal .',
#   {'entities': [(75, 83, 'ORG'), (84, 89, 'ORG'), (93, 101, 'ORG')]}),
#  ('Mbir maa ngi xewe woon ca Madinatul - Salaam , 22eelu fan ci weeru awril 2012 .',
#   {'entities': [(26, 35, 'LOC'),
#     (38, 44, 'LOC'),
#     (47, 53, 'DATE'),
#     (54, 57, 'DATE'),
#     (58, 60, 'DATE'),
#     (61, 66, 'DATE'),
#     (67, 72, 'DATE'),
#     (73, 77, 'DATE')]}),
#  ('Ñu ni déet - a - waay , gaa ñi ne Sëriñ bee leen jox ndigal .',
#   {'entities': [(34, 39, 'PER')]}),
#  ('Bi mu faatoo ci atum 1815 , kenn ci gëstukatu Frãs yi gënoon a mag te xelam màccoon ci xeet yiy dund , da koo fees , daggate ko , teqale cër yi .',
#   {'entities': [(16, 20, 'DATE'), (21, 25, 'DATE'), (46, 50, 'LOC')]}),
#  ('Jëmm ji moom , ñu lëmës ko ne ko gàcc ci kàggu - aada gi ñu duppe Musée de l’homme ” te nekk ca Pari , di péeyub réewum Frãs .',
#   {'entities': [(66, 71, 'ORG'),
#     (72, 74, 'ORG'),
#     (75, 82, 'ORG'),
#     (96, 100, 'LOC'),
#     (120, 124, 'LOC')]}),
#  ('Paap Juuf gi … Doonoon na njiit lu mag a mag ,',
#   {'entities': [(0, 4, 'PER'), (5, 9, 'PER')]}),
#  ('Li am kay , te muy dëgg , mooy ne ECO bi naalub CEDEAO la , moomeelam la , moom kepp a ci liggéey .',
#   {'entities': [(48, 54, 'ORG')]}),
#  ('Ndege , 1987 ba léegi ñooŋ ko doon togg , mooy jamono ja ñu taxawale naalub bennoo ñeel xaalisi kurél gi , doonte yéexoon nañ koo jëmmal .',
#   {'entities': [(8, 12, 'DATE')]}),
#  ('Ndaxte , ci atum 2000 lañ sumbaatoon liggéey bi .',
#   {'entities': [(12, 16, 'DATE'), (17, 21, 'DATE')]}),
#  ('Jamono jooju , jubluwaay bee doon , ca njëlbéen , fexe ba amal ñaareelu wàlluw xaalis ( zone monétaire – ECO ) bu waroon a boole réewi Afrig yiy làkk farañse ak réew yiy làkk purtugees .',
#   {'entities': [(135, 140, 'LOC')]}),
#  ('Liy xew ca bëj - gànnaaru Mali metti na , tiis na .',
#   {'entities': [(26, 30, 'LOC')]}),
#  ('Xanaa gisoo ni ñuy reye ndawi Mali yi , di saam seeni néew ?',
#   {'entities': [(30, 34, 'LOC')]}),
#  ('Boo weddee li ma lay wax , dugalal sa ñaari doom yi , Buuba ak Karim , ci làrme bi , yabal leen ñu xeexi .',
#   {'entities': [(54, 59, 'PER'), (63, 68, 'PER')]}),
#  ('Ngeen fàtte askanu Mali wi nga xam ne , sonn na , tàyyi na .',
#   {'entities': [(19, 23, 'LOC')]}),
#  ('Gaa , njaam gi wuññi woon na sunu sutura maam ya , nasaxal koomu Afrig .',
#   {'entities': [(65, 70, 'LOC')]}),
#  ('Moo waraloon njiitu réewu Farãs ba woon , Nikolaa Sarkoosi , ca waxtaan wa mu amaloon ci Ndakaaru gii , waxoon ne Afrig amul cosaan .',
#   {'entities': [(26, 31, 'LOC'),
#     (42, 49, 'PER'),
#     (50, 58, 'PER'),
#     (89, 97, 'LOC'),
#     (114, 119, 'LOC')]}),
#  ('Moo tax àndumaak Lewópóol Sedaar Seŋoor bi muy wax ne nooteel bi loraange ju jur njariñ la .',
#   {'entities': [(17, 25, 'PER'), (26, 32, 'PER'), (33, 39, 'PER')]}),
#  ('Ñaar fukki fan ak ñett ci weeru Mars ci atum 1972 la këru àttekaay bu Seŋoor àtte woon Omar Bolondeŋ Jóob , daan ko ñetti ati kaso yu mu waroon a tëdd .',
#   {'entities': [(0, 4, 'DATE'),
#     (5, 10, 'DATE'),
#     (11, 14, 'DATE'),
#     (15, 17, 'DATE'),
#     (18, 22, 'DATE'),
#     (23, 25, 'DATE'),
#     (26, 31, 'DATE'),
#     (32, 36, 'DATE'),
#     (37, 39, 'DATE'),
#     (40, 44, 'DATE'),
#     (45, 49, 'DATE'),
#     (70, 76, 'PER'),
#     (87, 91, 'PER'),
#     (92, 100, 'PER'),
#     (101, 105, 'PER')]}),
#  ('Mu doon xeex doxalinu Seŋoor wi aju woon ci li neex tubaab yi ba noppi worook bëgg - bëggu askanu Senegaal .',
# ...
#     (51, 55, 'PER'),
#     (56, 60, 'PER'),
#     (70, 74, 'DATE'),
#     (75, 79, 'DATE')]}),
#  ('Nee ñu Maki bariwul wax , day jëf : waaye am na nu , soo koy jëfe , looy doyeeti wax ?',
#   {'entities': [(7, 11, 'PER')]}),
#  ('Moom daal , wax ji yépp lii rekk la : Maki Sàll ak Tubaab yee bokk mbuus te li tee Senegaal jëm kanam , loolu ci la .',
#   {'entities': [(38, 42, 'PER'), (43, 47, 'PER'), (83, 91, 'LOC')]}),
#  ('Suñ ko deful , na ko doomi Afrig yi defal seen bopp , seet nu ñuy lijjantee seen digganteek njiit yi leen wor .',
#   {'entities': [(27, 32, 'LOC')]}),
#  ('Su gàcce gi dakkee la ëllëgu Afrig di door a leer .',
#   {'entities': [(29, 34, 'LOC')]}),
#  ('Boo demee gaaru Milaŋ am na ñuy fanaan ci mbedd yi .',
#   {'entities': [(16, 21, 'LOC')]}),
#  ('Te , Afrig , bu dul woon doxandéem yi ak Móodu - Móodu yiy daw di ñibbisi , yaakaar naa ni mbas mi doonu fi naane ñeex .',
#   {'entities': [(5, 10, 'LOC')]}),
#  ('Ci sunu réew mii moom , ñépp a ngiy fàttaliku bés bi Bill Gates daje woon ca Kanadaa ak Maki , ca weeru sàttumbar 2016 .',
#   {'entities': [(53, 57, 'PER'),
#     (58, 63, 'PER'),
#     (77, 84, 'LOC'),
#     (88, 92, 'PER'),
#     (104, 113, 'DATE'),
#     (114, 118, 'DATE')]}),
#  ('Waaye , ndawal àmbasadëeru Senegaal ca Kanadaa indi woon na ciy leeral , di biral ne , waxtaan woowule , dara sababu ko woon lu dul xeex feebar yu mel ni sëqat su bon si , sibbiru , sidaa ak it ni ñuy def ba yemale njureel gi .',
#   {'entities': [(27, 35, 'LOC'), (39, 46, 'LOC')]}),
#  ('Njiitul Sàndikaa Njabootu Alfabetisaasiyoŋ Nasiyonaal ( SNAN ) , nag , Ñoxor Ngom la tudd .',
#   {'entities': [(8, 16, 'ORG'),
#     (17, 25, 'ORG'),
#     (26, 42, 'ORG'),
#     (43, 53, 'ORG'),
#     (56, 60, 'ORG'),
#     (71, 76, 'PER'),
#     (77, 81, 'PER')]}),
#  ('Nun , Afrig bëj - saalum màndiŋu Saxara , dañ ko daan jëfandikoo lu bare laata ñu koy dakkal .',
#   {'entities': [(6, 11, 'LOC')]}),
#  ('Ñaari at ci ginnaaw , la kii di Usmaan Sonko sos pàrteem , tudde ko PASTEF ( ci nasaraan Patriotes du Sénégal pour le travail , l’éthique et la fraternité ) .',
#   {'entities': [(32, 38, 'PER'),
#     (39, 44, 'PER'),
#     (68, 74, 'ORG'),
#     (89, 98, 'ORG'),
#     (99, 101, 'ORG'),
#     (102, 109, 'ORG'),
#     (110, 114, 'ORG'),
#     (115, 117, 'ORG'),
#     (118, 125, 'ORG'),
#     (128, 137, 'ORG'),
#     (138, 140, 'ORG'),
#     (141, 143, 'ORG'),
#     (144, 154, 'ORG')]}),
#  ('Ci atum 2017 la sos itam Atlas , di ci liggéeyal boppam .',
#   {'entities': [(3, 7, 'DATE'), (8, 12, 'DATE'), (25, 30, 'ORG')]}),
#  ('Ni ko ay moroomam defe , Isaa Sàll wone na laabiir ñeel Xalifa Sàll mi ñu nëbb jant beek Kariim Wàdd , di ñaari wutaakon yi ñu seppi ci wote palug njiitu réew mi .',
#   {'entities': [(25, 29, 'PER'),
#     (30, 34, 'PER'),
#     (56, 62, 'PER'),
#     (63, 67, 'PER'),
#     (89, 95, 'PER'),
#     (96, 100, 'PER')]}),
#  ('Ndaxte , moom Isaa Sàll nee na , nguur gi dafa kootook yoon ngir xañ ñaar ñii seen àq ak seen yelleef .',
#   {'entities': [(14, 18, 'PER'), (19, 23, 'PER')]}),
#  ('Waaye kenn du ni Maki defu fi dara .', {'entities': [(17, 21, 'PER')]}),
#  ('ARTP booloo na ak waa Orange , Free ak Expresso ngir ñaax askan wi ci matuwaay yi nit ñi war jël ngir moytu Covid - 19 .',
#   {'entities': [(0, 4, 'ORG'),
#     (22, 28, 'ORG'),
#     (31, 35, 'ORG'),
#     (39, 47, 'ORG')]}),
#  ('Sunu réewi Afrig yi su ñu bennoowul xàll seen yoonu bopp , gisuma leen Mbaaw !',
#   {'entities': [(11, 16, 'LOC')]}),
#  ('Bu kenn ñakkatul doomam , ndax kon dinañu mën a jële feebar yu bari yi ci sunu réew mi , ak sax ci Afrig gépp ?',
#   {'entities': [(99, 104, 'LOC')]}),
#  ('Jaafara Sadiixu Fofana',
#   {'entities': [(0, 7, 'PER'), (8, 15, 'PER'), (16, 22, 'PER')]}),
#  ('Te , bees sukkandikoo ci gëstuy Porfesoor Raoult , ci dayo 1 ak 2 rekk lees mën a jëfandikoo niwaakin bi .',
#   {'entities': [(42, 48, 'PER')]}),
#  ('Léegi , PASTEF bett na ñépp jàll parenaas yi , njiitam wër na réew miy xamle yéeneem , muy soppi nekkinu askan wi , rawatina ñi gën a néew - doole .',
#   {'entities': [(8, 14, 'ORG')]}),
#  ('2012 – 2019 : juróom ñaari at yi mu toog ci jal bi , yeggali na liggéey yu bari yu Ablaay Wàdd sumboon .',
#   {'entities': [(0, 4, 'DATE'),
#     (7, 11, 'DATE'),
#     (83, 89, 'PER'),
#     (90, 94, 'PER')]}),
#  ('Nee ñu xaalis bu dul jeex la Maki leb bitim - réew dugal ko ci TER beek yeneen yi muy jébbal askan wi fan yii .',
#   {'entities': [(29, 33, 'PER')]}),
#  ('Ci loolu sax la waa Bennoo Bokk Yaakaar di sukkandiku naan Senegaal tegu na , ni oto rawante yu gaaw yooyu , ci yoonu yokkute , yànj ba dee , di def fiiw !',
#   {'entities': [(20, 26, 'ORG'),
#     (27, 31, 'ORG'),
#     (32, 39, 'ORG'),
#     (59, 67, 'LOC')]}),
#  ('Siin a ngi wallsi Senegaal',
#   {'entities': [(0, 4, 'LOC'), (18, 26, 'LOC')]}),
#  ('Laata ñu koy teg ci boppu OM , Paap Juuf jotoon naa nekk manatsëeru tàggat - yaram ci diirub benn at .',
#   {'entities': [(26, 28, 'ORG'), (31, 35, 'PER'), (36, 40, 'PER')]}),
#  ('Ci atum 2005 lañ ko tabb njiitalu Olympique de Marseille .',
#   {'entities': [(3, 7, 'DATE'),
#     (8, 12, 'DATE'),
#     (34, 43, 'ORG'),
#     (44, 46, 'ORG'),
#     (47, 56, 'ORG')]}),
#  ('Mu dib jaloore ju réy ndaxte OM bokk na ci ekibi futbalu Ërob yi gën a siiw te gën a mag .',
#   {'entities': [(29, 31, 'ORG'), (57, 61, 'LOC')]}),
#  ('Nun doomi Senegaal yi , dinanuy ànd dem ci daayira , dem julli jàkka waaye li nuy dimbalante ci sunu biir bariwul te bokk na ci li nu tax a des ginnaaw .',
#   {'entities': [(10, 18, 'LOC')]}),
#  ('Maanaam , keroog bañ nee mbas dikkal na réewum Siin , keroog laa doon jël samay matuwaay , tëj digi réew mi .',
#   {'entities': [(47, 51, 'LOC')]}),
#  ('Laaj yu am solo yooyu ñoo sampu tey te doomi Afrig yi , ak seen i njiit ñoo war a mànkoo joxe ci tontu lu leer , tey doon li gën ci xaley Afrig yi ak ëllëgu Afrig ci boppam .',
#   {'entities': [(45, 50, 'LOC'), (138, 143, 'LOC'), (157, 162, 'LOC')]}),
#  ('Waaye am ñu seen xel teey ci digganteem ak Ablaay Wàdd mi mu mel ni ku mu jébbal boppam .',
#   {'entities': [(43, 49, 'PER'), (50, 54, 'PER')]}),
#  ('Bi Góor - gi jógee bitim - réew , Sonko daa dakkal lépp li mu doon def , dem seeti ko .',
#   {'entities': [(34, 39, 'PER')]}),
#  ('Gisewaat nañu otel Terou bi ( Teeru bi lees war a bind ) .',
#   {'entities': [(14, 18, 'ORG'),
#     (19, 24, 'ORG'),
#     (25, 27, 'ORG'),
#     (30, 35, 'ORG'),
#     (36, 38, 'ORG')]}),
#  ('Du ñàkk Wàdd yedd ko , ni ko maam waree def ak sëtam .',
#   {'entities': [(8, 12, 'PER')]}),
#  ('Amaana tamit Sonko dig ko ne bés bu toogee ci jal bi , Karim Wàdd ak Xalifa Sàll lay njëkk a génne kaso .',
#   {'entities': [(13, 18, 'PER'),
#     (55, 60, 'PER'),
#     (61, 65, 'PER'),
#     (69, 75, 'PER'),
#     (76, 80, 'PER')]}),
#  ('Leneen lu ñépp di teg seen bët , moo di ne mbokki Maki Sàll yeek ñi koy jàppale , waxuñu dara , seen ceeb a ngi niin .',
#   {'entities': [(50, 54, 'PER'), (55, 59, 'PER')]}),
#  ('Noo yey laaj loolu ndax muy loppitaan yi di lekool yi , benn doxu ci : ku sa loxo jotul sa ginnaaw — te ñooñoo ëpp ci Senegaal — soo feebaree doo faju te sam njàng du sori .',
#   {'entities': [(118, 126, 'LOC')]}),
#  ('Réewum Siin mi jëkk a ame mbas mi fas naa yéene jàppale nguuru Senegaal ci xeex bi .',
#   {'entities': [(7, 11, 'LOC'), (63, 71, 'LOC')]}),
#  ('Ci noonu , àmbasaadu Siin ci Senegaal rotal nay xibaar yu bare ñeel ndimbal loolu :',
#   {'entities': [(21, 25, 'LOC'), (29, 37, 'LOC')]}),
#  ('Doonte ne Olympique de Marseille jëlul kub ci njiiteefam , ñépp a mànkoo ne , raaya bi OM amoon ci atum 2010 , liggéeyam a ko waral .',
#   {'entities': [(10, 19, 'ORG'),
#     (20, 22, 'ORG'),
#     (23, 32, 'ORG'),
#     (87, 89, 'ORG'),
#     (99, 103, 'DATE'),
#     (104, 108, 'DATE')]}),
#  ('Te , booba , OM toogoon na lu tollu ci 17i at yoo xam ne , jëlul raw - gàddug Farãs .',
#   {'entities': [(13, 15, 'ORG'), (78, 83, 'LOC')]}),
#  ('Ndax am na lu PASTEF jot a def ci xeexu mbas mi ?',
#   {'entities': [(14, 20, 'ORG')]}),
#  ('PAJ : Loo xam ci coowal ñakk biñ wax ne Afrig lañ ko bëgg a natte ?',
#   {'entities': [(40, 45, 'LOC')]}),
#  ('Ak lu mën a xew ginnaaw - ëllëg , kenn ci réew mi dootul fàtte doomu Maam Xadi Ngom ji .',
#   {'entities': [(69, 73, 'PER'), (74, 78, 'PER'), (79, 83, 'PER')]}),
#  ('Fi mu ne nii , Usmaan Sónko , Idirisaa Sekk , Isaa Sàll ak Madike Ñaŋ a ngi koy waaj a song .',
#   {'entities': [(15, 21, 'PER'),
#     (22, 27, 'PER'),
#     (30, 38, 'PER'),
#     (39, 43, 'PER'),
#     (46, 50, 'PER'),
#     (51, 55, 'PER'),
#     (59, 65, 'PER'),
#     (66, 69, 'PER')]}),
#  ('Li ñu war a fàttaliku rekk moo di ne Maki Sàll du neex a déjjati .',
#   {'entities': [(37, 41, 'PER'), (42, 46, 'PER')]}),
#  ('Laata ñuy agsi fii tey , tas na ñaari pàrti yi fi ëppoon doole , PS ak PDS .',
#   {'entities': [(65, 67, 'ORG'), (71, 74, 'ORG')]}),
#  ('Gone yaa ngi koy kókkali sax ci Facebook , naan alkaati Ndakaaru yi tey ku ñu gis ngay dawal oto bu bees ñu laaj la ndax Maki inaugurer na ko , soo leen nee déedéet ñu ni la taxaweel wet , mu ngi ci yoon wiy ñëw !',
#   {'entities': [(32, 40, 'ORG'), (56, 64, 'LOC'), (121, 125, 'PER')]}),
#  ('Am na yit ñu koy méngaleek Maxuréeja Géy mi doon yaakaar màndaa moom tamit ba taxoon koy leb xaalis bu bare di ndaataatallax .',
#   {'entities': [(27, 36, 'PER'), (37, 40, 'PER')]}),
#  ('Wànte ci filmu Usmaan Sémbéen bi , Maxuréeja rekk la àddinaam di mujjee yàqu - yaxeet .',
#   {'entities': [(15, 21, 'PER'), (22, 29, 'PER'), (35, 44, 'PER')]}),
#  ('Màndaawu 2019 bii moom , du ñàkk réewum lëmm la nar a salfaañe .',
#   {'entities': [(9, 13, 'DATE')]}),
#  ('Mel na ni Maki Sàll a ngi tayle ëllëgu goney Senegaal ngir rekk ga1ddu ndam li bésub 24 féewaryee bii ñuy séentu …',
#   {'entities': [(10, 14, 'PER'),
#     (15, 19, 'PER'),
#     (45, 53, 'LOC'),
#     (85, 87, 'DATE'),
#     (88, 97, 'DATE')]}),
#  ('Bi muy nekk ndawal futbalkat , Paap Juuf liggéey naak futbalkat yu ràññeeku .',
#   {'entities': [(31, 35, 'PER'), (36, 40, 'PER')]}),
#  ('Joseph - Antoine Bell ( góolu Kamerun ba woon ) ak Basile Boli ( futbalkatu Farãs ba woon , cosaanoo Koddiwaar ) la jëkk a teewal .',
#   {'entities': [(0, 6, 'PER'),
#     (9, 16, 'PER'),
#     (17, 21, 'PER'),
#     (30, 37, 'ORG'),
#     (51, 57, 'PER'),
#     (58, 62, 'PER'),
#     (76, 81, 'LOC'),
#     (101, 110, 'LOC')]}),
#  ('Gannaaw bi , sosoon na sosete Mondial Promotion ci atum 1989 , teewal futbalkat yu bare yu ci mel ni : Marcel Desailly , Didier Drogba , Bernard Lama , William Gallas , Rigobert Song , Pirès , Coupet , Francois - Omam - Biyik , Laurent Blanc , Samir Nasri …',
#   {'entities': [(30, 37, 'ORG'),
#     (38, 47, 'ORG'),
#     (51, 55, 'DATE'),
#     (56, 60, 'DATE'),
#     (103, 109, 'PER'),
#     (110, 118, 'PER'),
#     (121, 127, 'PER'),
#     (128, 134, 'PER'),
#     (137, 144, 'PER'),
#     (145, 149, 'PER'),
#     (152, 159, 'PER'),
#     (160, 166, 'PER'),
#     (169, 177, 'PER'),
#     (178, 182, 'PER'),
#     (185, 190, 'PER'),
#     (193, 199, 'PER'),
#     (202, 210, 'PER'),
#     (213, 217, 'PER'),
#     (220, 225, 'PER'),
#     (228, 235, 'PER'),
#     (236, 241, 'PER'),
#     (244, 249, 'PER'),
#     (250, 255, 'PER')]}),
#  ('Ngeen may ma tuuti ma leeral mbir : PASTEF , maye xaalis taxu koo jóg te du cëram .',
#   {'entities': [(36, 42, 'ORG')]}),
#  ('Dafa di , Senegaal , dafa am lu politiseŋ yi gëmloo askan wi , mooy ne : ab pàrti politig , dafa war di joxe xaalis .',
#   {'entities': [(10, 18, 'LOC')]}),
#  ('Ba tax na , Senegaal mënta jëm kanam .', {'entities': [(12, 20, 'LOC')]}),
#  ('Demal Etaasini , 2i làng ñoo fa am .', {'entities': [(6, 14, 'LOC')]}),
#  ('Foo mënti dem ci àddina si , noonu la , ba mu des Afrig .',
#   {'entities': [(50, 55, 'LOC')]}),
#  ('Te xaalis boobu , dërëmu PASTEF ak yeneen làngi politig yaa ngi ci biir .',
#   {'entities': [(25, 31, 'ORG')]}),
#  ('Mu mel ne Afrig tollooti na ci sélébeyoon bi mu tollu woon ca 1963 .',
#   {'entities': [(10, 15, 'LOC'), (62, 66, 'DATE')]}),
#  ('Jamono jooju , benn ci ñaari yoon lanu mënoon a jaar : yoonu Ufuwet Buwaañi ak Lewópóol Seŋoor , maanaam ànd ak doxandéem bi mu nuy wommat , walla yoonu Kwame Nkrumah ak Séex Anta Jóob , di tekki ne Afrig war naa mën demal boppam ci kow nu bennoo , di xàccandoo di dóorandoo .',
#   {'entities': [(61, 67, 'PER'),
#     (68, 75, 'PER'),
#     (79, 87, 'PER'),
#     (88, 94, 'PER'),
#     (153, 158, 'PER'),
#     (159, 166, 'PER'),
#     (170, 174, 'PER'),
#     (175, 179, 'PER'),
#     (180, 184, 'PER'),
#     (199, 204, 'LOC')]}),
#  ('Mamadu Jàllo ak Bubakar Bóris Jóob',
#   {'entities': [(0, 6, 'PER'),
#     (7, 12, 'PER'),
#     (16, 23, 'PER'),
#     (24, 29, 'PER'),
#     (30, 34, 'PER')]}),
#  ('nee ñu , ràllumaanu Siin bu siiw bi sos Groupe Alibaba , Ma Yun ( Jack Ma ) dina may réewu Afrig mu ne 100 000 mask , 1 000 yérey aaru ñeel doktoor yi , 1 000 écrans faciaux ak 200 000 saytukaayi Covid - 19 ;',
#   {'entities': [(20, 24, 'LOC'),
#     (40, 46, 'ORG'),
#     (47, 54, 'ORG'),
#     (57, 59, 'PER'),
#     (60, 63, 'PER'),
#     (66, 70, 'PER'),
#     (71, 73, 'PER'),
#     (91, 96, 'LOC')]}),
#  ('Paap njiit lu ñépp fonkoon la , joxoon ko cër ndax ku',
#   {'entities': [(0, 4, 'PER')]}),
#  ('Kon daal PASTEF deful dara ngir mbas mi ?', {'entities': [(9, 15, 'ORG')]}),
#  ('Yoonu Seŋoor ak Ufuwet woowu nu tànnoon moo nu tax a tollu tey fii .',
#   {'entities': [(6, 12, 'PER'), (16, 22, 'PER')]}),
#  ('Ñaareelu mbir mi mooy ne , bu dee am na ñu soxla ñakk jamono jii , réewi Ërob yeek yu Amerig yi la .',
#   {'entities': [(73, 77, 'LOC'), (86, 92, 'LOC')]}),
#  ('Teg ci ne , nun réewi Afrig yi , dañuy faral di ñakk xale yi ca ba ñuy gone .',
#   {'entities': [(22, 27, 'LOC')]}),
#  ('Amaana mu aar ñu bare ci doomi Afrig yi ci Covid - 19 bi .',
#   {'entities': [(31, 36, 'LOC')]}),
#  ('Usmaan Sonko nee na bu bés ba ñëwee dina soppi politig ci boppam : Yàlla bu ko politig soppi , moom Usmaan Sonko , nun nu nekkati fiy dunde yaakaar .',
#   {'entities': [(0, 6, 'PER'),
#     (7, 12, 'PER'),
#     (100, 106, 'PER'),
#     (107, 112, 'PER')]}),
#  ('àmbasaad bi waxaat na ne , Groupe BGI dina may Senegaal 500 saytukaayi Covid - 19 ;',
#   {'entities': [(27, 33, 'ORG'), (34, 37, 'ORG'), (47, 55, 'LOC')]}),
#  ('Naam , c i sunu wàllu bopp , dama ne woon gaa ñi PASTEF amul dara lu muy joxe ndax li ma wax léegi .',
#   {'entities': [(49, 55, 'ORG')]}),
#  ('Lenn , daal , mën ngeen k o o def , mooy boole li PASTEF di joxe yépp nataal ko ngir ñu xam ne lii PASTEF a ko joxe ; wànte bu kenn xam ne kii walla kee moo jot lii walla lee … Léegi nag k om yéen a ma laaj , dina leen tont : yóbbul nan ci loppitaan yi ak bérébi fajukaay yi ay jumtukaayi paj , te loolu def nan ko ci biir réew mépp daanaka .',
#   {'entities': [(50, 56, 'ORG'), (99, 105, 'ORG')]}),
#  ('Biralees na ko ci sunu xëtu Facebook .', {'entities': [(28, 36, 'ORG')]}),
#  ('Móodu - Móodook Faatu - Faatu yi bokk PASTEF tamit yónnee nañ xaalis bu takku .',
#   {'entities': [(38, 44, 'ORG')]}),
#  ('Waaye , ni Senegaal tëdde , di réew mu nit ñi war a dimbalante rekk a tax .',
#   {'entities': [(11, 19, 'LOC')]}),
#  ('Ndax bii yoon , dinanu takk sunu fit , tànn yoon wi nu Nkrumaak Séex Anta xàllal ciy jamono ?',
#   {'entities': [(55, 63, 'PER'), (64, 68, 'PER'), (69, 73, 'PER')]}),
#  ('Bennoo bokk benn jëmu mooy tax Afrig am doole ak naataange .',
#   {'entities': [(31, 36, 'LOC')]}),
#  ('Yaakaar naa ne doomi Afrig dofuñu te kenn mënatu leen a nax .',
#   {'entities': [(21, 26, 'LOC')]}),
#  ('liggéeykati Siin yi dinañ lëkkook yu Senegaal yi ngir soppi loppitaanu Yaay - Doom bu Jamñaajo ngir jagleel ko way - tawat yi ;',
#   {'entities': [(12, 16, 'LOC'), (37, 45, 'LOC'), (86, 94, 'LOC')]}),
#  ('Te , jamono jii , njiit yu mel ni Paap Juuf lañ tumurànke .',
#   {'entities': [(34, 38, 'PER'), (39, 43, 'PER')]}),
#  ('Yenn njiiti Afrig yi te Maki Sàll gën cee fës ñu ngi ñaan ñu baal leen bor yi ñu ameel yenn réew yi .',
#   {'entities': [(12, 17, 'LOC'), (24, 28, 'PER'), (29, 33, 'PER')]}),
#  ('Askani Afrig , ëllëg , ëllëgu booloo la , ëllëgu moom - sa - bopp la !',
#   {'entities': [(7, 12, 'LOC')]}),
#  ('Gis naa Maki Sàll soppi tuuti ci waxin wi , naan yalwaanuñu , ni ñu dàqe àpp gi doy na ñu .',
#   {'entities': [(8, 12, 'PER'), (13, 17, 'PER')]}),
#  ('Jawriñ Abdulaay Juuf Saar kalaame na yoon ñiy sos ak a weddi naan koronaawiris amul sax Senegaal , rawati - na Tuubaa .',
#   {'entities': [(7, 15, 'PER'),
#     (16, 20, 'PER'),
#     (21, 25, 'PER'),
#     (88, 96, 'LOC'),
#     (111, 117, 'LOC')]})]

# %%
model = ner.fit(train_data, 75, 32, 0.5)
# Out:
# {'ner': 8179.08870783742}  Iter n:  0
# {'ner': 2776.9794977890106}  Iter n:  1
# {'ner': 2072.2307997187845}  Iter n:  2
# {'ner': 1778.65288297868}  Iter n:  3
# {'ner': 1550.2671765010643}  Iter n:  4
# {'ner': 1421.9011126027372}  Iter n:  5
# {'ner': 1248.8723479423081}  Iter n:  6
# {'ner': 1072.3792438477624}  Iter n:  7
# {'ner': 929.3846038907363}  Iter n:  8
# {'ner': 851.3473664674036}  Iter n:  9
# {'ner': 772.9753691156399}  Iter n:  10
# {'ner': 674.4358066215862}  Iter n:  11
# {'ner': 642.2582403622405}  Iter n:  12
# {'ner': 560.1120726906752}  Iter n:  13
# {'ner': 549.4749393486775}  Iter n:  14
# {'ner': 488.0868038406417}  Iter n:  15
# {'ner': 430.9982072524866}  Iter n:  16
# {'ner': 422.4623120954685}  Iter n:  17
# {'ner': 396.1295364810721}  Iter n:  18
# {'ner': 344.4586908203446}  Iter n:  19
# {'ner': 310.38255518217943}  Iter n:  20
# {'ner': 260.54838837873444}  Iter n:  21
# {'ner': 301.6628026417836}  Iter n:  22
# {'ner': 283.1952797663606}  Iter n:  23
# {'ner': 264.35451482567083}  Iter n:  24
# {'ner': 291.86643095222536}  Iter n:  25
# {'ner': 229.81151423353248}  Iter n:  26
# {'ner': 250.22239919738553}  Iter n:  27
# {'ner': 207.6018566538395}  Iter n:  28
# {'ner': 177.9711575033765}  Iter n:  29
# {'ner': 216.7246779627}  Iter n:  30
# {'ner': 192.68512588896456}  Iter n:  31
# {'ner': 207.04652260815683}  Iter n:  32
# {'ner': 214.40635951586447}  Iter n:  33
# {'ner': 184.12466323828988}  Iter n:  34
# {'ner': 182.39854283645548}  Iter n:  35
# {'ner': 178.70166255091974}  Iter n:  36
# {'ner': 193.38010260691496}  Iter n:  37
# {'ner': 160.15823504854552}  Iter n:  38
# {'ner': 159.9231557584038}  Iter n:  39
# {'ner': 150.87103683196148}  Iter n:  40
# {'ner': 153.41701718722575}  Iter n:  41
# {'ner': 167.57968019860704}  Iter n:  42
# {'ner': 148.7523479913097}  Iter n:  43
# {'ner': 135.7241379646571}  Iter n:  44
# {'ner': 127.76934179634831}  Iter n:  45
# {'ner': 110.4547080722196}  Iter n:  46
# {'ner': 159.19748954491985}  Iter n:  47
# {'ner': 127.74014630107264}  Iter n:  48
# {'ner': 160.9456890355679}  Iter n:  49
# {'ner': 117.02861962645252}  Iter n:  50
# {'ner': 108.09307467354567}  Iter n:  51
# {'ner': 109.46022191725434}  Iter n:  52
# {'ner': 105.81386601568668}  Iter n:  53
# {'ner': 82.26975448802997}  Iter n:  54
# {'ner': 116.14985152974916}  Iter n:  55
# {'ner': 107.26861656501686}  Iter n:  56
# {'ner': 108.58331310662932}  Iter n:  57
# {'ner': 102.1774722130883}  Iter n:  58
# {'ner': 93.55078122989265}  Iter n:  59
# {'ner': 97.83347043860172}  Iter n:  60
# {'ner': 103.80554684162567}  Iter n:  61
# {'ner': 114.12980572800899}  Iter n:  62
# {'ner': 99.2356666362591}  Iter n:  63
# {'ner': 105.63329449806942}  Iter n:  64
# {'ner': 112.6086432000749}  Iter n:  65
# {'ner': 86.40573050413728}  Iter n:  66
# {'ner': 81.31699023109552}  Iter n:  67
# {'ner': 100.28659733364942}  Iter n:  68
# {'ner': 84.4609483399101}  Iter n:  69
# {'ner': 92.8524196934329}  Iter n:  70
# {'ner': 94.97728245309872}  Iter n:  71
# {'ner': 83.38363758294578}  Iter n:  72
# {'ner': 73.63570622446072}  Iter n:  73
# {'ner': 80.2892567222498}  Iter n:  74

# %%
model = spacy.load("NER")
# Out:
# c:\Users\Don Arhona\Desktop\IA_Competition\venv\Lib\site-packages\spacy\util.py:910: UserWarning: [W095] Model 'xx_pipeline' (0.0.0) was trained with spaCy v3.7.2 and may not be 100% compatible with the current version (3.7.1). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %%
y_true, y_pred = ner.predict(model, test_data)

# %%
# N_iter : 50, size : 16, drop : 0.4

# Calculez les scores de performance
report = classification_report(y_true, y_pred)
print(report)
# Recuperation du weigthed avg qui donne le score en prennant compte des dimension disproportionnees de chaque classe
score = float(report.split()[-2])
# Out:
#               precision    recall  f1-score   support
#
#       B-DATE       0.28      0.36      0.31        70
#        B-LOC       0.72      0.66      0.69       211
#        B-ORG       0.24      0.31      0.27        55
#        B-PER       0.31      0.44      0.37       176
#       I-DATE       1.00      0.05      0.09       153
#        I-LOC       0.00      0.00      0.00         4
#        I-ORG       0.00      0.00      0.00        13
#        I-PER       0.88      0.30      0.44       193
#            O       0.97      0.99      0.98     10807
#
#     accuracy                           0.94     11682
#    macro avg       0.49      0.34      0.35     11682
# weighted avg       0.94      0.94      0.93     11682

# %%
N_iter : 75; size : 16; drop : 0.4

#Calculez les scores de performance
report = classification_report(y_true, y_pred)
print(report)
#Recuperation du weigthed avg qui donne le score en prennant compte des dimension disproportionnees de chaque classe
score = float(report.split()[-2])
# Out:
#               precision    recall  f1-score   support
#
#       B-DATE       0.28      0.36      0.31        70
#        B-LOC       0.72      0.66      0.69       211
#        B-ORG       0.24      0.31      0.27        55
#        B-PER       0.31      0.44      0.37       176
#       I-DATE       1.00      0.05      0.09       153
#        I-LOC       0.00      0.00      0.00         4
#        I-ORG       0.00      0.00      0.00        13
#        I-PER       0.88      0.30      0.44       193
#            O       0.97      0.99      0.98     10807
#
#     accuracy                           0.94     11682
#    macro avg       0.49      0.34      0.35     11682
# weighted avg       0.94      0.94      0.93     11682

# %%
N_iter : 50; size : 16; drop : 0.4

#Calculez les scores de performance
report = classification_report(y_true, y_pred)
print(report)
# Recuperation du weigthed avg qui donne le score en prennant compte des dimension disproportionnees de chaque classe
score = float(report.split()[-2])
# Out:
#               precision    recall  f1-score   support
#
#       B-DATE       0.28      0.36      0.31        70
#        B-LOC       0.72      0.66      0.69       211
#        B-ORG       0.24      0.31      0.27        55
#        B-PER       0.31      0.44      0.37       176
#       I-DATE       1.00      0.05      0.09       153
#        I-LOC       0.00      0.00      0.00         4
#        I-ORG       0.00      0.00      0.00        13
#        I-PER       0.88      0.30      0.44       193
#            O       0.97      0.99      0.98     10807
#
#     accuracy                           0.94     11682
#    macro avg       0.49      0.34      0.35     11682
# weighted avg       0.94      0.94      0.93     11682

# %%
N_iter : 150; size : 16; drop : 0.4

# Calculez les scores de performance
report = classification_report(y_true, y_pred)
print(report)
# Recuperation du weigthed avg qui donne le score en prennant compte des dimension disproportionnees de chaque classe
score = float(report.split()[-2])
# Out:
#               precision    recall  f1-score   support
#
#       B-DATE       0.28      0.36      0.31        70
#        B-LOC       0.72      0.66      0.69       211
#        B-ORG       0.24      0.31      0.27        55
#        B-PER       0.31      0.44      0.37       176
#       I-DATE       1.00      0.05      0.09       153
#        I-LOC       0.00      0.00      0.00         4
#        I-ORG       0.00      0.00      0.00        13
#        I-PER       0.88      0.30      0.44       193
#            O       0.97      0.99      0.98     10807
#
#     accuracy                           0.94     11682
#    macro avg       0.49      0.34      0.35     11682
# weighted avg       0.94      0.94      0.93     11682

# %%
N_iter : 100; size : 32; drop : 0.5

# Calculez les scores de performance
report = classification_report(y_true, y_pred)
print(report)
# Recuperation du weigthed avg qui donne le score en prennant compte des dimension disproportionnees de chaque classe
score = float(report.split()[-2])
# Out:
#               precision    recall  f1-score   support
#
#       B-DATE       0.28      0.36      0.31        70
#        B-LOC       0.72      0.66      0.69       211
#        B-ORG       0.24      0.31      0.27        55
#        B-PER       0.31      0.44      0.37       176
#       I-DATE       1.00      0.05      0.09       153
#        I-LOC       0.00      0.00      0.00         4
#        I-ORG       0.00      0.00      0.00        13
#        I-PER       0.88      0.30      0.44       193
#            O       0.97      0.99      0.98     10807
#
#     accuracy                           0.94     11682
#    macro avg       0.49      0.34      0.35     11682
# weighted avg       0.94      0.94      0.93     11682

# %%
import spacy

# Charger le modèle SpaCy (remplacez le nom du modèle par le vôtre)
ner_model = spacy.load("NER")

# Sauvegarder le modèle dans un répertoire
ner_model.to_disk(r"C:\Users\Don Arhona\Desktop\IA_Competition\NerApp\ModelNER")
# Out:
# c:\Users\Don Arhona\Desktop\IA_Competition\venv\Lib\site-packages\spacy\util.py:910: UserWarning: [W095] Model 'xx_pipeline' (0.0.0) was trained with spaCy v3.7.2 and may not be 100% compatible with the current version (3.7.1). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
